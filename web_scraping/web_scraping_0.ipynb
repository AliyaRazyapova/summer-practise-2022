# %% [raw]
# <img src="https://raw.githubusercontent.com/hse-econ-data-science/eds_spring_2020/master/sem05_parsing/image/take_all.png" height="300" width="1200">
#
# # <center> Науки о данных <br>  <br> Собираем данные в python </center>
#
#
# **Привет**
# **Текст, выделенный полужирным шрифтом**

# %% [markdown]
# ## Зачем собирать данные автоматически?
#
# <br>
#
# <br>
#
# <center>
# <img src="https://raw.githubusercontent.com/hse-econ-data-science/eds_spring_2020/master/sem05_parsing/image/aaaaaa.png" width="500">

# %% [markdown]
# ## Что такое HTML?
#
# **HTML (HyperText Markup Language)**  — это такой же язык разметки как Markdown или LaTeX. Он является стандартным для написания различных сайтов. Команды в таком языке называются **тегами**. Если открыть абсолютно любой сайт, нажать на правую кнопку мышки, а после нажать `View page source`, то перед вами предстанет HTML скелет этого сайта.
#
# Вот так можно открыть html-код стартовой яндекса, найти в нём новость из топа и немного её изменить. Понятное дело, что вы так меняете html-страничку только на своём компьютере (клиенте). На сервере яндекса остаётся исходная версия. Когда вы обновите страничку все правки исчезнут. Однако никто вам не запрещает ворваться вк в какую-нибудь переписку, открыть её код, поменять текст нескольких сообщений и наделать скринов для мемов.
#
# <br>
# <img src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/gifs/yandex.gif" width="700">
# <br>
#
#
# HTML-страница это ни что иное, как набор вложенных тегов. Можно заметить, например, следующие теги:
#
# - `<title>` – заголовок страницы
# - `<h1>…<h6>` – заголовки разных уровней
# - `<p>` – абзац (paragraph)
# - `<div>` – выделения фрагмента документа с целью изменения вида содержимого
# - `<table>` – прорисовка таблицы
# - `<tr>` – разделитель для строк в таблице
# - `<td>` – разделитель для столбцов в таблице
# - `<b>` – устанавливает жирное начертание шрифта
#
# Обычно команда `<...>` открывает тег, а  `</...>` закрывает его. Все, что находится между этими двумя командами, подчиняется правилу, которое диктует тег. Например, все, что находится между `<p>` и  `</p>` — это отдельный абзац.
#
# Теги образуют своеобразное дерево с корнем в теге `<html>` и разбивают страницу на разные логические кусочки. У каждого тега есть свои потомки (дети) — те теги, которые вложены в него и свои родители.
#
# Например, HTML-древо страницы может выглядеть вот так:
#
#
# ````
# <html>
# <head> Заголовок </head>
# <body>
#     <div>
#         Первый кусок текста со своими свойствами
#     </div>
#     <div>
#         Второй кусок текста
#             <b>
#                 Третий, жирный кусок
#             </b>
#     </div>
#     Четвёртый кусок текста
# </body>
# </html>
# ````
#
# Можно работать с этим html как с текстом, а можно как с деревом. Обход этого дерева и есть парсинг веб-страницы. Мы всего лишь будем находить нужные нам узлы среди всего этого разнообразия и забирать из них информацию!
#
# <center>
# <img src="https://raw.githubusercontent.com/hse-econ-data-science/eds_spring_2020/master/sem05_parsing/image/tree.png" width="450">

# %% [markdown]
# # Скачиваем табличку с сайта ЦБ

# %% [markdown]
# Доступ к веб-станицам позволяет получать модуль requests. Подгрузим его. Если у вас не установлен этот модуль, то нужно установить:  `pip install requests`.

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.5.30)

# %%
import requests

# %%
resp = requests.get('https://cbr.ru/currency_base/daily/')

# %% [markdown]
# Внутри response лежит html-разметка странички, которую мы парсим.

# %%
resp
# Out:
# <Response [200]>

# %%
resp.content[:100]
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    \r\n\r\n<meta http-equiv="Content-Type" content="text/html; chars'

# %% [markdown]
# Выглядит неудобоваримо, как насчет сварить из этого дела что-то покрасивее? Например, прекрасный суп.
#
# <img align="center" src="https://raw.githubusercontent.com/hse-econ-data-science/eds_spring_2020/master/sem05_parsing/image/alisa.jpg" height="200" width="200">
#
# Пакет **[`bs4`](https://www.crummy.com/software/BeautifulSoup/)**, a.k.a **BeautifulSoup** был назван в честь стишка про красивый суп из Алисы в стране чудес. Эта совершенно волшебная библиотека, которая из сырого и необработанного HTML (или XML) кода страницы выдаст вам структурированный массив данных, по которому очень удобно искать необходимые теги, классы, атрибуты, тексты и прочие элементы веб страниц.
#
# > Пакет под названием `BeautifulSoup` — скорее всего, не то, что вам нужно. Это третья версия (*Beautiful Soup 3*), а мы будем использовать четвертую. Так что нам нужен пакет `beautifulsoup4`. Чтобы было совсем весело, при импорте нужно указывать другое название пакета — `bs4`, а импортировать функцию под названием `BeautifulSoup`.

# %%
from bs4 import BeautifulSoup

# %%
tree = BeautifulSoup(resp.content, 'html.parser')
tree

# %% [markdown]
# В коде страницы мы можем найти где именно для каждого курса лежит основная информация. Видно, что она находится внутри тега `table`, для которого прописан класс `data` (грубо говоря, в html класс задаёт оформление соотвествующего кусочка страницы).
#
#
# Вытащим информацию о курсе валюты

# %%
# нашли табличку
table = tree.find_all('table', {'class' : 'data'})[0]
table
# Out:
# <table class="data">
# <tbody>
# <tr>
# <th>Цифр. код</th>
# <th>Букв. код</th>
# <th>Единиц</th>
# <th>Валюта</th>
# <th>Курс</th>
# </tr>
# <tr>
# <td>036</td>
# <td>AUD</td>
# <td>1</td>
# <td>Австралийский доллар</td>
# <td>54,0167</td>
# </tr>
# <tr>
# <td>944</td>
# <td>AZN</td>
# <td>1</td>
# <td>Азербайджанский манат</td>
# <td>43,2267</td>
# </tr>
# <tr>
# <td>051</td>
# <td>AMD</td>
# <td>100</td>
# <td>Армянских драмов</td>
# <td>14,8985</td>
# </tr>
# <tr>
# <td>933</td>
# <td>BYN</td>
# <td>1</td>
# <td>Белорусский рубль</td>
# <td>29,1495</td>
# </tr>
# <tr>
# <td>975</td>
# <td>BGN</td>
# <td>1</td>
# <td>Болгарский лев</td>
# <td>44,3866</td>
# </tr>
# <tr>
# <td>986</td>
# <td>BRL</td>
# <td>1</td>
# <td>Бразильский реал</td>
# <td>14,2038</td>
# </tr>
# <tr>
# <td>348</td>
# <td>HUF</td>
# <td>100</td>
# <td>Венгерских форинтов</td>
# <td>24,8628</td>
# </tr>
# <tr>
# <td>410</td>
# <td>KRW</td>
# <td>1000</td>
# <td>Вон Республики Корея</td>
# <td>62,8933</td>
# </tr>
# <tr>
# <td>344</td>
# <td>HKD</td>
# <td>10</td>
# <td>Гонконгских долларов</td>
# <td>94,4338</td>
# </tr>
# <tr>
# <td>208</td>
# <td>DKK</td>
# <td>1</td>
# <td>Датская крона</td>
# <td>11,6743</td>
# </tr>
# <tr>
# <td>840</td>
# <td>USD</td>
# <td>1</td>
# <td>Доллар США</td>
# <td>73,4421</td>
# </tr>
# <tr>
# <td>978</td>
# <td>EUR</td>
# <td>1</td>
# <td>Евро</td>
# <td>86,9114</td>
# </tr>
# <tr>
# <td>356</td>
# <td>INR</td>
# <td>100</td>
# <td>Индийских рупий</td>
# <td>99,7258</td>
# </tr>
# <tr>
# <td>398</td>
# <td>KZT</td>
# <td>100</td>
# <td>Казахстанских тенге</td>
# <td>17,1996</td>
# </tr>
# <tr>
# <td>124</td>
# <td>CAD</td>
# <td>1</td>
# <td>Канадский доллар</td>
# <td>57,8375</td>
# </tr>
# <tr>
# <td>417</td>
# <td>KGS</td>
# <td>100</td>
# <td>Киргизских сомов</td>
# <td>86,6295</td>
# </tr>
# <tr>
# <td>156</td>
# <td>CNY</td>
# <td>1</td>
# <td>Китайский юань</td>
# <td>11,3651</td>
# </tr>
# <tr>
# <td>498</td>
# <td>MDL</td>
# <td>10</td>
# <td>Молдавских леев</td>
# <td>41,8951</td>
# </tr>
# <tr>
# <td>934</td>
# <td>TMT</td>
# <td>1</td>
# <td>Новый туркменский манат</td>
# <td>21,0135</td>
# </tr>
# <tr>
# <td>578</td>
# <td>NOK</td>
# <td>10</td>
# <td>Норвежских крон</td>
# <td>84,1493</td>
# </tr>
# <tr>
# <td>985</td>
# <td>PLN</td>
# <td>1</td>
# <td>Польский злотый</td>
# <td>19,2242</td>
# </tr>
# <tr>
# <td>946</td>
# <td>RON</td>
# <td>1</td>
# <td>Румынский лей</td>
# <td>17,5489</td>
# </tr>
# <tr>
# <td>960</td>
# <td>XDR</td>
# <td>1</td>
# <td>СДР (специальные права заимствования)</td>
# <td>104,7270</td>
# </tr>
# <tr>
# <td>702</td>
# <td>SGD</td>
# <td>1</td>
# <td>Сингапурский доллар</td>
# <td>54,5389</td>
# </tr>
# <tr>
# <td>972</td>
# <td>TJS</td>
# <td>10</td>
# <td>Таджикских сомони</td>
# <td>64,7923</td>
# </tr>
# <tr>
# <td>949</td>
# <td>TRY</td>
# <td>10</td>
# <td>Турецких лир</td>
# <td>87,4071</td>
# </tr>
# <tr>
# <td>860</td>
# <td>UZS</td>
# <td>10000</td>
# <td>Узбекских сумов</td>
# <td>68,6681</td>
# </tr>
# <tr>
# <td>980</td>
# <td>UAH</td>
# <td>10</td>
# <td>Украинских гривен</td>
# <td>27,4653</td>
# </tr>
# <tr>
# <td>826</td>
# <td>GBP</td>
# <td>1</td>
# <td>Фунт стерлингов Соединенного королевства</td>
# <td>101,0196</td>
# </tr>
# <tr>
# <td>203</td>
# <td>CZK</td>
# <td>10</td>
# <td>Чешских крон</td>
# <td>34,1957</td>
# </tr>
# <tr>
# <td>752</td>
# <td>SEK</td>
# <td>10</td>
# <td>Шведских крон</td>
# <td>85,1779</td>
# </tr>
# <tr>
# <td>756</td>
# <td>CHF</td>
# <td>1</td>
# <td>Швейцарский франк</td>
# <td>79,8631</td>
# </tr>
# <tr>
# <td>710</td>
# <td>ZAR</td>
# <td>10</td>
# <td>Южноафриканских рэндов</td>
# <td>51,1966</td>
# </tr>
# <tr>
# <td>392</td>
# <td>JPY</td>
# <td>100</td>
# <td>Японских иен</td>
# <td>66,6595</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ***Задание: позже вернуться к этой задаче и формить результат запроса в виде таблицы Pandas ***

# %% [markdown]
# ## Качаем цены на книги
#
# * Хотим собрать [цены на книги](http://books.toscrape.com)
# * Руками долго, напишем код на питоне

# %%
import requests  

response = requests.get('http://books.toscrape.com/catalogue/page-1.html')
response
# Out:
# <Response [200]>

# %% [markdown]
# Благословенный 200 ответ - соединение установлено и данные получены, всё чудесно! Если попытаться перейти на несуществующую страницу, то можно получить, например, знаменитую ошибку 404.

# %%
requests.get('http://books.toscrape.com/big_scholarship')
# Out:
# <Response [404]>

# %% [markdown]
# Внутри response лежит html-разметка странички, которую мы парсим.

# %%
response.content[:1000]
# Out:
# b'\n\n<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    All products | Books to Scrape - Sandbox\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:30" />\n        <meta name="description" content="" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="shortcut icon" href="../static/oscar/fav'

# %%
from bs4 import BeautifulSoup

# распарсили страничку в дерево 
tree = BeautifulSoup(response.content, 'html.parser')
tree
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:30" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="../static/oscar/favicon.ico" rel="shortcut icon"/>
# <link href="../static/oscar/css/styles.css" rel="stylesheet" type="text/css"/>
# <link href="../static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.css" rel="stylesheet"/>
# <link href="../static/oscar/css/datetimepicker.css" rel="stylesheet" type="text/css"/>
# </head>
# <body class="default" id="default">
# <header class="header container-fluid">
# <div class="page_inner">
# <div class="row">
# <div class="col-sm-8 h1"><a href="../index.html">Books to Scrape</a><small> We love being scraped!</small>
# </div>
# </div>
# </div>
# </header>
# <div class="container-fluid page">
# <div class="page_inner">
# <ul class="breadcrumb">
# <li>
# <a href="../index.html">Home</a>
# </li>
# <li class="active">All products</li>
# </ul>
# <div class="row">
# <aside class="sidebar col-sm-4 col-md-3">
# <div id="promotions_left">
# </div>
# <div class="side_categories">
# <ul class="nav nav-list">
# <li>
# <a href="category/books_1/index.html">
#
#                                 Books
#
#                         </a>
# <ul>
# <li>
# <a href="category/books/travel_2/index.html">
#
#                                 Travel
#
#                         </a>
# </li>
# <li>
# <a href="category/books/mystery_3/index.html">
#
#                                 Mystery
#
#                         </a>
# </li>
# <li>
# <a href="category/books/historical-fiction_4/index.html">
#
#                                 Historical Fiction
#
#                         </a>
# </li>
# <li>
# <a href="category/books/sequential-art_5/index.html">
#
#                                 Sequential Art
#
#                         </a>
# </li>
# <li>
# <a href="category/books/classics_6/index.html">
#
#                                 Classics
#
#                         </a>
# </li>
# <li>
# <a href="category/books/philosophy_7/index.html">
#
#                                 Philosophy
#
#                         </a>
# </li>
# <li>
# <a href="category/books/romance_8/index.html">
#
#                                 Romance
#
#                         </a>
# </li>
# <li>
# <a href="category/books/womens-fiction_9/index.html">
#
#                                 Womens Fiction
#
#                         </a>
# </li>
# <li>
# <a href="category/books/fiction_10/index.html">
#
#                                 Fiction
#
#                         </a>
# </li>
# <li>
# <a href="category/books/childrens_11/index.html">
#
#                                 Childrens
#
#                         </a>
# </li>
# <li>
# <a href="category/books/religion_12/index.html">
#
#                                 Religion
#
#                         </a>
# </li>
# <li>
# <a href="category/books/nonfiction_13/index.html">
#
#                                 Nonfiction
#
#                         </a>
# </li>
# <li>
# <a href="category/books/music_14/index.html">
#
#                                 Music
#
#                         </a>
# </li>
# <li>
# <a href="category/books/default_15/index.html">
#
#                                 Default
#
#                         </a>
# </li>
# <li>
# <a href="category/books/science-fiction_16/index.html">
#
#                                 Science Fiction
#
#                         </a>
# </li>
# <li>
# <a href="category/books/sports-and-games_17/index.html">
#
#                                 Sports and Games
#
#                         </a>
# </li>
# <li>
# <a href="category/books/add-a-comment_18/index.html">
#
#                                 Add a comment
#
#                         </a>
# </li>
# <li>
# <a href="category/books/fantasy_19/index.html">
#
#                                 Fantasy
#
#                         </a>
# </li>
# <li>
# <a href="category/books/new-adult_20/index.html">
#
#                                 New Adult
#
#                         </a>
# </li>
# <li>
# <a href="category/books/young-adult_21/index.html">
#
#                                 Young Adult
#
#                         </a>
# </li>
# <li>
# <a href="category/books/science_22/index.html">
#
#                                 Science
#
#                         </a>
# </li>
# <li>
# <a href="category/books/poetry_23/index.html">
#
#                                 Poetry
#
#                         </a>
# </li>
# <li>
# <a href="category/books/paranormal_24/index.html">
#
#                                 Paranormal
#
#                         </a>
# </li>
# <li>
# <a href="category/books/art_25/index.html">
#
#                                 Art
#
#                         </a>
# </li>
# <li>
# <a href="category/books/psychology_26/index.html">
#
#                                 Psychology
#
#                         </a>
# </li>
# <li>
# <a href="category/books/autobiography_27/index.html">
#
#                                 Autobiography
#
#                         </a>
# </li>
# <li>
# <a href="category/books/parenting_28/index.html">
#
#                                 Parenting
#
#                         </a>
# </li>
# <li>
# <a href="category/books/adult-fiction_29/index.html">
#
#                                 Adult Fiction
#
#                         </a>
# </li>
# <li>
# <a href="category/books/humor_30/index.html">
#
#                                 Humor
#
#                         </a>
# </li>
# <li>
# <a href="category/books/horror_31/index.html">
#
#                                 Horror
#
#                         </a>
# </li>
# <li>
# <a href="category/books/history_32/index.html">
#
#                                 History
#
#                         </a>
# </li>
# <li>
# <a href="category/books/food-and-drink_33/index.html">
#
#                                 Food and Drink
#
#                         </a>
# </li>
# <li>
# <a href="category/books/christian-fiction_34/index.html">
#
#                                 Christian Fiction
#
#                         </a>
# </li>
# <li>
# <a href="category/books/business_35/index.html">
#
#                                 Business
#
#                         </a>
# </li>
# <li>
# <a href="category/books/biography_36/index.html">
#
#                                 Biography
#
#                         </a>
# </li>
# <li>
# <a href="category/books/thriller_37/index.html">
#
#                                 Thriller
#
#                         </a>
# </li>
# <li>
# <a href="category/books/contemporary_38/index.html">
#
#                                 Contemporary
#
#                         </a>
# </li>
# <li>
# <a href="category/books/spirituality_39/index.html">
#
#                                 Spirituality
#
#                         </a>
# </li>
# <li>
# <a href="category/books/academic_40/index.html">
#
#                                 Academic
#
#                         </a>
# </li>
# <li>
# <a href="category/books/self-help_41/index.html">
#
#                                 Self Help
#
#                         </a>
# </li>
# <li>
# <a href="category/books/historical_42/index.html">
#
#                                 Historical
#
#                         </a>
# </li>
# <li>
# <a href="category/books/christian_43/index.html">
#
#                                 Christian
#
#                         </a>
# </li>
# <li>
# <a href="category/books/suspense_44/index.html">
#
#                                 Suspense
#
#                         </a>
# </li>
# <li>
# <a href="category/books/short-stories_45/index.html">
#
#                                 Short Stories
#
#                         </a>
# </li>
# <li>
# <a href="category/books/novels_46/index.html">
#
#                                 Novels
#
#                         </a>
# </li>
# <li>
# <a href="category/books/health_47/index.html">
#
#                                 Health
#
#                         </a>
# </li>
# <li>
# <a href="category/books/politics_48/index.html">
#
#                                 Politics
#
#                         </a>
# </li>
# <li>
# <a href="category/books/cultural_49/index.html">
#
#                                 Cultural
#
#                         </a>
# </li>
# <li>
# <a href="category/books/erotica_50/index.html">
#
#                                 Erotica
#
#                         </a>
# </li>
# <li>
# <a href="category/books/crime_51/index.html">
#
#                                 Crime
#
#                         </a>
# </li>
# </ul></li>
# </ul>
# </div>
# </aside>
# <div class="col-sm-8 col-md-9">
# <div class="page-header action">
# <h1>All products</h1>
# </div>
# <div id="messages">
# </div>
# <div id="promotions">
# </div>
# <form class="form-horizontal" method="get">
# <div style="display:none">
# </div>
# <strong>1000</strong> results - showing <strong>1</strong> to <strong>20</strong>.
#
#
#
#
#     </form>
# <section>
# <div class="alert alert-warning" role="alert"><strong>Warning!</strong> This is a demo website for web scraping purposes. Prices and ratings here were randomly assigned and have no real meaning.</div>
# <div>
# <ol class="row">
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="tipping-the-velvet_999/index.html"><img alt="Tipping the Velvet" class="thumbnail" src="../media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg"/></a>
# </div>
# <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="tipping-the-velvet_999/index.html" title="Tipping the Velvet">Tipping the Velvet</a></h3>
# <div class="product_price">
# <p class="price_color">£53.74</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="soumission_998/index.html"><img alt="Soumission" class="thumbnail" src="../media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg"/></a>
# </div>
# <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="soumission_998/index.html" title="Soumission">Soumission</a></h3>
# <div class="product_price">
# <p class="price_color">£50.10</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="sharp-objects_997/index.html"><img alt="Sharp Objects" class="thumbnail" src="../media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg"/></a>
# </div>
# <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="sharp-objects_997/index.html" title="Sharp Objects">Sharp Objects</a></h3>
# <div class="product_price">
# <p class="price_color">£47.82</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="sapiens-a-brief-history-of-humankind_996/index.html"><img alt="Sapiens: A Brief History of Humankind" class="thumbnail" src="../media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg"/></a>
# </div>
# <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="sapiens-a-brief-history-of-humankind_996/index.html" title="Sapiens: A Brief History of Humankind">Sapiens: A Brief History ...</a></h3>
# <div class="product_price">
# <p class="price_color">£54.23</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="the-requiem-red_995/index.html"><img alt="The Requiem Red" class="thumbnail" src="../media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg"/></a>
# </div>
# <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="the-requiem-red_995/index.html" title="The Requiem Red">The Requiem Red</a></h3>
# <div class="product_price">
# <p class="price_color">£22.65</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="the-dirty-little-secrets-of-getting-your-dream-job_994/index.html"><img alt="The Dirty Little Secrets of Getting Your Dream Job" class="thumbnail" src="../media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg"/></a>
# </div>
# <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="the-dirty-little-secrets-of-getting-your-dream-job_994/index.html" title="The Dirty Little Secrets of Getting Your Dream Job">The Dirty Little Secrets ...</a></h3>
# <div class="product_price">
# <p class="price_color">£33.34</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html"><img alt="The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull" class="thumbnail" src="../media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html" title="The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull">The Coming Woman: A ...</a></h3>
# <div class="product_price">
# <p class="price_color">£17.93</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html"><img alt="The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics" class="thumbnail" src="../media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg"/></a>
# </div>
# <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html" title="The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics">The Boys in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">£22.60</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="the-black-maria_991/index.html"><img alt="The Black Maria" class="thumbnail" src="../media/cache/58/46/5846057e28022268153beff6d352b06c.jpg"/></a>
# </div>
# <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="the-black-maria_991/index.html" title="The Black Maria">The Black Maria</a></h3>
# <div class="product_price">
# <p class="price_color">£52.15</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="starving-hearts-triangular-trade-trilogy-1_990/index.html"><img alt="Starving Hearts (Triangular Trade Trilogy, #1)" class="thumbnail" src="../media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg"/></a>
# </div>
# <p class="star-rating Two">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="starving-hearts-triangular-trade-trilogy-1_990/index.html" title="Starving Hearts (Triangular Trade Trilogy, #1)">Starving Hearts (Triangular Trade ...</a></h3>
# <div class="product_price">
# <p class="price_color">£13.99</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="shakespeares-sonnets_989/index.html"><img alt="Shakespeare's Sonnets" class="thumbnail" src="../media/cache/10/48/1048f63d3b5061cd2f424d20b3f9b666.jpg"/></a>
# </div>
# <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="shakespeares-sonnets_989/index.html" title="Shakespeare's Sonnets">Shakespeare's Sonnets</a></h3>
# <div class="product_price">
# <p class="price_color">£20.66</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="set-me-free_988/index.html"><img alt="Set Me Free" class="thumbnail" src="../media/cache/5b/88/5b88c52633f53cacf162c15f4f823153.jpg"/></a>
# </div>
# <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="set-me-free_988/index.html" title="Set Me Free">Set Me Free</a></h3>
# <div class="product_price">
# <p class="price_color">£17.46</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html"><img alt="Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)" class="thumbnail" src="../media/cache/94/b1/94b1b8b244bce9677c2f29ccc890d4d2.jpg"/></a>
# </div>
# <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html" title="Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)">Scott Pilgrim's Precious Little ...</a></h3>
# <div class="product_price">
# <p class="price_color">£52.29</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="rip-it-up-and-start-again_986/index.html"><img alt="Rip it Up and Start Again" class="thumbnail" src="../media/cache/81/c4/81c4a973364e17d01f217e1188253d5e.jpg"/></a>
# </div>
# <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="rip-it-up-and-start-again_986/index.html" title="Rip it Up and Start Again">Rip it Up and ...</a></h3>
# <div class="product_price">
# <p class="price_color">£35.02</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html"><img alt="Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991" class="thumbnail" src="../media/cache/54/60/54607fe8945897cdcced0044103b10b6.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html" title="Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991">Our Band Could Be ...</a></h3>
# <div class="product_price">
# <p class="price_color">£57.25</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="olio_984/index.html"><img alt="Olio" class="thumbnail" src="../media/cache/55/33/553310a7162dfbc2c6d19a84da0df9e1.jpg"/></a>
# </div>
# <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="olio_984/index.html" title="Olio">Olio</a></h3>
# <div class="product_price">
# <p class="price_color">£23.88</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html"><img alt="Mesaerion: The Best Science Fiction Stories 1800-1849" class="thumbnail" src="../media/cache/09/a3/09a3aef48557576e1a85ba7efea8ecb7.jpg"/></a>
# </div>
# <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html" title="Mesaerion: The Best Science Fiction Stories 1800-1849">Mesaerion: The Best Science ...</a></h3>
# <div class="product_price">
# <p class="price_color">£37.59</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="libertarianism-for-beginners_982/index.html"><img alt="Libertarianism for Beginners" class="thumbnail" src="../media/cache/0b/bc/0bbcd0a6f4bcd81ccb1049a52736406e.jpg"/></a>
# </div>
# <p class="star-rating Two">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="libertarianism-for-beginners_982/index.html" title="Libertarianism for Beginners">Libertarianism for Beginners</a></h3>
# <div class="product_price">
# <p class="price_color">£51.33</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="its-only-the-himalayas_981/index.html"><img alt="It's Only the Himalayas" class="thumbnail" src="../media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg"/></a>
# </div>
# <p class="star-rating Two">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="its-only-the-himalayas_981/index.html" title="It's Only the Himalayas">It's Only the Himalayas</a></h3>
# <div class="product_price">
# <p class="price_color">£45.17</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>
# </ol>
# <div>
# <ul class="pager">
# <li class="current">
#
#                 Page 1 of 50
#
#             </li>
# <li class="next"><a href="page-2.html">next</a></li>
# </ul>
# </div>
# </div>
# </section>
# </div>
# </div><!-- /row -->
# </div><!-- /page_inner -->
# </div><!-- /container-fluid -->
# <footer class="footer container-fluid">
# </footer>
# <!-- jQuery -->
# <script src="http://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js"></script>
# <script>window.jQuery || document.write('<script src="../static/oscar/js/jquery/jquery-1.9.1.min.js"><\/script>')</script>
# <!-- Twitter Bootstrap -->
# <script src="../static/oscar/js/bootstrap3/bootstrap.min.js" type="text/javascript"></script>
# <!-- Oscar -->
# <script charset="utf-8" src="../static/oscar/js/oscar/ui.js" type="text/javascript"></script>
# <script charset="utf-8" src="../static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.js" type="text/javascript"></script>
# <script charset="utf-8" src="../static/oscar/js/bootstrap-datetimepicker/locales/bootstrap-datetimepicker.all.js" type="text/javascript"></script>
# <script type="text/javascript">
#             $(function() {
#
#
#
#     oscar.init();
#
#     oscar.search.init();
#
#             });
#         </script>
# <!-- Version: N/A -->
# </body>
# </html>

# %% [markdown]
# Внутри переменной `tree` теперь лежит дерево из тегов, по которому мы можем совершенно спокойно бродить.

# %%
tree.html.head.title
# Out:
# <title>
#     All products | Books to Scrape - Sandbox
# </title>

# %% [markdown]
# Более того, зная адрес элемента, мы сразу можем найти его. Например, вот так в коде страницы мы можем найти где именно для каждой книги лежит основная информация. Видно, что она находится внутри тега `article`, для которого прописан класс `product_pod` (грубо говоря, в html класс задаёт оформление соотвествующего кусочка страницы).
#
#
# Вытащим информацию о книге из этого тега.

# %%
books = tree.find_all('article', {'class' : 'product_pod'})
books[0]
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %% [markdown]
# Полученный после поиска объект также обладает структурой bs4. Поэтому можно продолжить искать нужные нам объекты уже в нём.

# %%
type(books[0])
# Out:
# bs4.element.Tag

# %%
books[0].find('p', {'class': 'price_color'}).text
# Out:
# '£51.77'

# %% [markdown]
# Обратите внимание, что для поиска есть как минимум два метода: `find` и `find_all`. Если несколько элементов на странице обладают указанным адресом, то метод `find` вернёт только самый первый. Чтобы найти все элементы с таким адресом, нужно использовать метод `find_all`. На выход будет выдан список.
#
# Кроме содержимого у тегов часто есть атрибуты. Например, у названия книги есть атрибуты `title` и `href`:

# %%
books[0].h3
# Out:
# <h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>

# %% [markdown]
# Их тоже можно вытащить.

# %%
books[0].h3.a.get('href')
# Out:
# 'a-light-in-the-attic_1000/index.html'

# %%
books[0].h3.a.get('title')
# Out:
# 'A Light in the Attic'

# %% [markdown]
# А ещё по этим атрибутам можно искать интересующие нас кусочки страницы.

# %%
tree.find_all('a', {'title': 'A Light in the Attic'})
# Out:
# [<a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a>]

# %% [markdown]
# Обратите внимание, что на сайте все книги лежат на разных страничках. Если попробовать потыкать их, можно заметить, что в ссылке будет меняться атрибут `page`. Значит, если мы хотим собрать все книги, надо создать кучу ссылок с разным `page` внутри цикла.
#
#
# Давайте запишем весь код для сбора книг в виде функции. На вход она будет принимать номер странички, которую надо скачать.

# %%
infa = [ ]
    
for book in books:
       infa.append({'price': book.find('p', {'class': 'price_color'}).text,
                  
                    'title': book.h3.a.get('title')})

# %%
import requests

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'}
r = requests.get('https://www.amazon.com', headers)
r.status_code
# Out:
# 503

# %%
infa
# Out:
# [{'href': 'a-light-in-the-attic_1000/index.html',
#   'price': '£51.77',
#   'title': 'A Light in the Attic'},
#  {'href': 'tipping-the-velvet_999/index.html',
#   'price': '£53.74',
#   'title': 'Tipping the Velvet'},
#  {'href': 'soumission_998/index.html',
#   'price': '£50.10',
#   'title': 'Soumission'},
#  {'href': 'sharp-objects_997/index.html',
#   'price': '£47.82',
#   'title': 'Sharp Objects'},
#  {'href': 'sapiens-a-brief-history-of-humankind_996/index.html',
#   'price': '£54.23',
#   'title': 'Sapiens: A Brief History of Humankind'},
#  {'href': 'the-requiem-red_995/index.html',
#   'price': '£22.65',
#   'title': 'The Requiem Red'},
#  {'href': 'the-dirty-little-secrets-of-getting-your-dream-job_994/index.html',
#   'price': '£33.34',
#   'title': 'The Dirty Little Secrets of Getting Your Dream Job'},
#  {'href': 'the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html',
#   'price': '£17.93',
#   'title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull'},
#  {'href': 'the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html',
#   'price': '£22.60',
#   'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics'},
#  {'href': 'the-black-maria_991/index.html',
#   'price': '£52.15',
#   'title': 'The Black Maria'},
#  {'href': 'starving-hearts-triangular-trade-trilogy-1_990/index.html',
#   'price': '£13.99',
#   'title': 'Starving Hearts (Triangular Trade Trilogy, #1)'},
#  {'href': 'shakespeares-sonnets_989/index.html',
#   'price': '£20.66',
#   'title': "Shakespeare's Sonnets"},
#  {'href': 'set-me-free_988/index.html',
#   'price': '£17.46',
#   'title': 'Set Me Free'},
#  {'href': 'scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html',
#   'price': '£52.29',
#   'title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)"},
#  {'href': 'rip-it-up-and-start-again_986/index.html',
#   'price': '£35.02',
#   'title': 'Rip it Up and Start Again'},
#  {'href': 'our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html',
#   'price': '£57.25',
#   'title': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991'},
#  {'href': 'olio_984/index.html', 'price': '£23.88', 'title': 'Olio'},
#  {'href': 'mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html',
#   'price': '£37.59',
#   'title': 'Mesaerion: The Best Science Fiction Stories 1800-1849'},
#  {'href': 'libertarianism-for-beginners_982/index.html',
#   'price': '£51.33',
#   'title': 'Libertarianism for Beginners'},
#  {'href': 'its-only-the-himalayas_981/index.html',
#   'price': '£45.17',
#   'title': "It's Only the Himalayas"},
#  {'href': 'in-her-wake_980/index.html',
#   'price': '£12.84',
#   'title': 'In Her Wake'},
#  {'href': 'how-music-works_979/index.html',
#   'price': '£37.32',
#   'title': 'How Music Works'},
#  {'href': 'foolproof-preserving-a-guide-to-small-batch-jams-jellies-pickles-condiments-and-more-a-foolproof-guide-to-making-small-batch-jams-jellies-pickles-condiments-and-more_978/index.html',
#   'price': '£30.52',
#   'title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More'},
#  {'href': 'chase-me-paris-nights-2_977/index.html',
#   'price': '£25.27',
#   'title': 'Chase Me (Paris Nights #2)'},
#  {'href': 'black-dust_976/index.html',
#   'price': '£34.53',
#   'title': 'Black Dust'},
#  {'href': 'birdsong-a-story-in-pictures_975/index.html',
#   'price': '£54.64',
#   'title': 'Birdsong: A Story in Pictures'},
#  {'href': 'americas-cradle-of-quarterbacks-western-pennsylvanias-football-factory-from-johnny-unitas-to-joe-montana_974/index.html',
#   'price': '£22.50',
#   'title': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana"},
#  {'href': 'aladdin-and-his-wonderful-lamp_973/index.html',
#   'price': '£53.13',
#   'title': 'Aladdin and His Wonderful Lamp'},
#  {'href': 'worlds-elsewhere-journeys-around-shakespeares-globe_972/index.html',
#   'price': '£40.30',
#   'title': 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe'},
#  {'href': 'wall-and-piece_971/index.html',
#   'price': '£44.18',
#   'title': 'Wall and Piece'},
#  {'href': 'the-four-agreements-a-practical-guide-to-personal-freedom_970/index.html',
#   'price': '£17.66',
#   'title': 'The Four Agreements: A Practical Guide to Personal Freedom'},
#  {'href': 'the-five-love-languages-how-to-express-heartfelt-commitment-to-your-mate_969/index.html',
#   'price': '£31.05',
#   'title': 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate'},
#  {'href': 'the-elephant-tree_968/index.html',
#   'price': '£23.82',
#   'title': 'The Elephant Tree'},
#  {'href': 'the-bear-and-the-piano_967/index.html',
#   'price': '£36.89',
#   'title': 'The Bear and the Piano'},
#  {'href': 'sophies-world_966/index.html',
#   'price': '£15.94',
#   'title': "Sophie's World"},
#  {'href': 'penny-maybe_965/index.html',
#   'price': '£33.29',
#   'title': 'Penny Maybe'},
#  {'href': 'maude-1883-1993she-grew-up-with-the-country_964/index.html',
#   'price': '£18.02',
#   'title': 'Maude (1883-1993):She Grew Up with the country'},
#  {'href': 'in-a-dark-dark-wood_963/index.html',
#   'price': '£19.63',
#   'title': 'In a Dark, Dark Wood'},
#  {'href': 'behind-closed-doors_962/index.html',
#   'price': '£52.22',
#   'title': 'Behind Closed Doors'},
#  {'href': 'you-cant-bury-them-all-poems_961/index.html',
#   'price': '£33.63',
#   'title': "You can't bury them all: Poems"},
#  {'href': 'slow-states-of-collapse-poems_960/index.html',
#   'price': '£57.31',
#   'title': 'Slow States of Collapse: Poems'},
#  {'href': 'reasons-to-stay-alive_959/index.html',
#   'price': '£26.41',
#   'title': 'Reasons to Stay Alive'},
#  {'href': 'private-paris-private-10_958/index.html',
#   'price': '£47.61',
#   'title': 'Private Paris (Private #10)'},
#  {'href': 'higherselfie-wake-up-your-life-free-your-soul-find-your-tribe_957/index.html',
#   'price': '£23.11',
#   'title': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.'},
#  {'href': 'without-borders-wanderlove-1_956/index.html',
#   'price': '£45.07',
#   'title': 'Without Borders (Wanderlove #1)'},
#  {'href': 'when-we-collided_955/index.html',
#   'price': '£31.77',
#   'title': 'When We Collided'},
#  {'href': 'we-love-you-charlie-freeman_954/index.html',
#   'price': '£50.27',
#   'title': 'We Love You, Charlie Freeman'},
#  {'href': 'untitled-collection-sabbath-poems-2014_953/index.html',
#   'price': '£14.27',
#   'title': 'Untitled Collection: Sabbath Poems 2014'},
#  {'href': 'unseen-city-the-majesty-of-pigeons-the-discreet-charm-of-snails-other-wonders-of-the-urban-wilderness_952/index.html',
#   'price': '£44.18',
#   'title': 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness'},
#  {'href': 'unicorn-tracks_951/index.html',
#   'price': '£18.78',
#   'title': 'Unicorn Tracks'},
#  {'href': 'unbound-how-eight-technologies-made-us-human-transformed-society-and-brought-our-world-to-the-brink_950/index.html',
#   'price': '£25.52',
#   'title': 'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink'},
#  {'href': 'tsubasa-world-chronicle-2-tsubasa-world-chronicle-2_949/index.html',
#   'price': '£16.28',
#   'title': 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)'},
#  {'href': 'throwing-rocks-at-the-google-bus-how-growth-became-the-enemy-of-prosperity_948/index.html',
#   'price': '£31.12',
#   'title': 'Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity'},
#  {'href': 'this-one-summer_947/index.html',
#   'price': '£19.49',
#   'title': 'This One Summer'},
#  {'href': 'thirst_946/index.html', 'price': '£17.27', 'title': 'Thirst'},
#  {'href': 'the-torch-is-passed-a-harding-family-story_945/index.html',
#   'price': '£19.09',
#   'title': 'The Torch Is Passed: A Harding Family Story'},
#  {'href': 'the-secret-of-dreadwillow-carse_944/index.html',
#   'price': '£56.13',
#   'title': 'The Secret of Dreadwillow Carse'},
#  {'href': 'the-pioneer-woman-cooks-dinnertime-comfort-classics-freezer-food-16-minute-meals-and-other-delicious-ways-to-solve-supper_943/index.html',
#   'price': '£56.41',
#   'title': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!'},
#  {'href': 'the-past-never-ends_942/index.html',
#   'price': '£56.50',
#   'title': 'The Past Never Ends'},
#  {'href': 'the-natural-history-of-us-the-fine-art-of-pretending-2_941/index.html',
#   'price': '£45.22',
#   'title': 'The Natural History of Us (The Fine Art of Pretending #2)'},
#  {'href': 'the-nameless-city-the-nameless-city-1_940/index.html',
#   'price': '£38.16',
#   'title': 'The Nameless City (The Nameless City #1)'},
#  {'href': 'the-murder-that-never-was-forensic-instincts-5_939/index.html',
#   'price': '£54.11',
#   'title': 'The Murder That Never Was (Forensic Instincts #5)'},
#  {'href': 'the-most-perfect-thing-inside-and-outside-a-birds-egg_938/index.html',
#   'price': '£42.96',
#   'title': "The Most Perfect Thing: Inside (and Outside) a Bird's Egg"},
#  {'href': 'the-mindfulness-and-acceptance-workbook-for-anxiety-a-guide-to-breaking-free-from-anxiety-phobias-and-worry-using-acceptance-and-commitment-therapy_937/index.html',
#   'price': '£23.89',
#   'title': 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy'},
#  {'href': 'the-life-changing-magic-of-tidying-up-the-japanese-art-of-decluttering-and-organizing_936/index.html',
#   'price': '£16.77',
#   'title': 'The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing'},
#  {'href': 'the-inefficiency-assassin-time-management-tactics-for-working-smarter-not-longer_935/index.html',
#   'price': '£20.59',
#   'title': 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer'},
#  {'href': 'the-gutsy-girl-escapades-for-your-life-of-epic-adventure_934/index.html',
#   'price': '£37.13',
#   'title': 'The Gutsy Girl: Escapades for Your Life of Epic Adventure'},
#  {'href': 'the-electric-pencil-drawings-from-inside-state-hospital-no-3_933/index.html',
#   'price': '£56.06',
#   'title': 'The Electric Pencil: Drawings from Inside State Hospital No. 3'},
#  {'href': 'the-death-of-humanity-and-the-case-for-life_932/index.html',
#   'price': '£58.11',
#   'title': 'The Death of Humanity: and the Case for Life'},
#  {'href': 'the-bulletproof-diet-lose-up-to-a-pound-a-day-reclaim-energy-and-focus-upgrade-your-life_931/index.html',
#   'price': '£49.05',
#   'title': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life'},
#  {'href': 'the-art-forger_930/index.html',
#   'price': '£40.76',
#   'title': 'The Art Forger'},
#  {'href': 'the-age-of-genius-the-seventeenth-century-and-the-birth-of-the-modern-mind_929/index.html',
#   'price': '£19.73',
#   'title': 'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind'},
#  {'href': 'the-activists-tao-te-ching-ancient-advice-for-a-modern-revolution_928/index.html',
#   'price': '£32.24',
#   'title': "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution"},
#  {'href': 'spark-joy-an-illustrated-master-class-on-the-art-of-organizing-and-tidying-up_927/index.html',
#   'price': '£41.83',
#   'title': 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up'},
#  {'href': 'soul-reader_926/index.html',
#   'price': '£39.58',
#   'title': 'Soul Reader'},
#  {'href': 'security_925/index.html', 'price': '£39.25', 'title': 'Security'},
#  {'href': 'saga-volume-6-saga-collected-editions-6_924/index.html',
#   'price': '£25.02',
#   'title': 'Saga, Volume 6 (Saga (Collected Editions) #6)'},
#  {'href': 'saga-volume-5-saga-collected-editions-5_923/index.html',
#   'price': '£51.04',
#   'title': 'Saga, Volume 5 (Saga (Collected Editions) #5)'},
#  {'href': 'reskilling-america-learning-to-labor-in-the-twenty-first-century_922/index.html',
#   'price': '£19.83',
#   'title': 'Reskilling America: Learning to Labor in the Twenty-First Century'},
#  {'href': 'rat-queens-vol-3-demons-rat-queens-collected-editions-11-15_921/index.html',
#   'price': '£50.40',
#   'title': 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)'},
#  {'href': 'princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html',
#   'price': '£13.61',
#   'title': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)'},
#  {'href': 'princess-between-worlds-wide-awake-princess-5_919/index.html',
#   'price': '£13.34',
#   'title': 'Princess Between Worlds (Wide-Awake Princess #5)'},
#  {'href': 'pop-gun-war-volume-1-gift_918/index.html',
#   'price': '£18.97',
#   'title': 'Pop Gun War, Volume 1: Gift'},
#  {'href': 'political-suicide-missteps-peccadilloes-bad-calls-backroom-hijinx-sordid-pasts-rotten-breaks-and-just-plain-dumb-mistakes-in-the-annals-of-american-politics_917/index.html',
#   'price': '£36.28',
#   'title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics'},
#  {'href': 'patience_916/index.html', 'price': '£10.16', 'title': 'Patience'},
#  {'href': 'outcast-vol-1-a-darkness-surrounds-him-outcast-1_915/index.html',
#   'price': '£15.44',
#   'title': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)'},
#  {'href': 'orange-the-complete-collection-1-orange-the-complete-collection-1_914/index.html',
#   'price': '£48.41',
#   'title': 'orange: The Complete Collection 1 (orange: The Complete Collection #1)'},
#  {'href': 'online-marketing-for-busy-authors-a-step-by-step-guide_913/index.html',
#   'price': '£46.35',
#   'title': 'Online Marketing for Busy Authors: A Step-By-Step Guide'},
#  {'href': 'on-a-midnight-clear_912/index.html',
#   'price': '£14.07',
#   'title': 'On a Midnight Clear'},
#  {'href': 'obsidian-lux-1_911/index.html',
#   'price': '£14.86',
#   'title': 'Obsidian (Lux #1)'},
#  {'href': 'my-paris-kitchen-recipes-and-stories_910/index.html',
#   'price': '£33.37',
#   'title': 'My Paris Kitchen: Recipes and Stories'},
#  {'href': 'masks-and-shadows_909/index.html',
#   'price': '£56.40',
#   'title': 'Masks and Shadows'},
#  {'href': 'mama-tried-traditional-italian-cooking-for-the-screwed-crude-vegan-and-tattooed_908/index.html',
#   'price': '£14.02',
#   'title': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed'},
#  {'href': 'lumberjanes-vol-2-friendship-to-the-max-lumberjanes-5-8_907/index.html',
#   'price': '£46.91',
#   'title': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)'},
#  {'href': 'lumberjanes-vol-1-beware-the-kitten-holy-lumberjanes-1-4_906/index.html',
#   'price': '£45.61',
#   'title': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)'},
#  {'href': 'lumberjanes-vol-3-a-terrible-plan-lumberjanes-9-12_905/index.html',
#   'price': '£19.92',
#   'title': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)'},
#  {'href': 'layered-baking-building-and-styling-spectacular-cakes_904/index.html',
#   'price': '£40.11',
#   'title': 'Layered: Baking, Building, and Styling Spectacular Cakes'},
#  {'href': 'judo-seven-steps-to-black-belt-an-introductory-guide-for-beginners_903/index.html',
#   'price': '£53.90',
#   'title': 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)'},
#  {'href': 'join_902/index.html', 'price': '£35.67', 'title': 'Join'},
#  {'href': 'in-the-country-we-love-my-family-divided_901/index.html',
#   'price': '£22.00',
#   'title': 'In the Country We Love: My Family Divided'},
#  {'href': 'immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html',
#   'price': '£57.36',
#   'title': 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine'},
#  {'href': 'i-hate-fairyland-vol-1-madly-ever-after-i-hate-fairyland-compilations-1-5_899/index.html',
#   'price': '£29.17',
#   'title': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)'},
#  {'href': 'i-am-a-hero-omnibus-volume-1_898/index.html',
#   'price': '£54.63',
#   'title': 'I am a Hero Omnibus Volume 1'},
#  {'href': 'how-to-be-miserable-40-strategies-you-already-use_897/index.html',
#   'price': '£46.03',
#   'title': 'How to Be Miserable: 40 Strategies You Already Use'},
#  {'href': 'her-backup-boyfriend-the-sorensen-family-1_896/index.html',
#   'price': '£33.97',
#   'title': 'Her Backup Boyfriend (The Sorensen Family #1)'},
#  {'href': 'giant-days-vol-2-giant-days-5-8_895/index.html',
#   'price': '£22.11',
#   'title': 'Giant Days, Vol. 2 (Giant Days #5-8)'},
#  {'href': 'forever-and-forever-the-courtship-of-henry-longfellow-and-fanny-appleton_894/index.html',
#   'price': '£29.69',
#   'title': 'Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton'},
#  {'href': 'first-and-first-five-boroughs-3_893/index.html',
#   'price': '£15.97',
#   'title': 'First and First (Five Boroughs #3)'},
#  {'href': 'fifty-shades-darker-fifty-shades-2_892/index.html',
#   'price': '£21.96',
#   'title': 'Fifty Shades Darker (Fifty Shades #2)'},
#  {'href': 'everydata-the-misinformation-hidden-in-the-little-data-you-consume-every-day_891/index.html',
#   'price': '£54.35',
#   'title': 'Everydata: The Misinformation Hidden in the Little Data You Consume Every Day'},
#  {'href': 'dont-be-a-jerk-and-other-practical-advice-from-dogen-japans-greatest-zen-master_890/index.html',
#   'price': '£37.97',
#   'title': "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master"},
#  {'href': 'danganronpa-volume-1_889/index.html',
#   'price': '£51.99',
#   'title': 'Danganronpa Volume 1'},
#  {'href': 'crown-of-midnight-throne-of-glass-2_888/index.html',
#   'price': '£43.29',
#   'title': 'Crown of Midnight (Throne of Glass #2)'},
#  {'href': 'codename-baboushka-volume-1-the-conclave-of-death_887/index.html',
#   'price': '£36.72',
#   'title': 'Codename Baboushka, Volume 1: The Conclave of Death'},
#  {'href': 'camp-midnight_886/index.html',
#   'price': '£17.08',
#   'title': 'Camp Midnight'},
#  {'href': 'call-the-nurse-true-stories-of-a-country-nurse-on-a-scottish-isle_885/index.html',
#   'price': '£29.14',
#   'title': 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle'},
#  {'href': 'burning_884/index.html', 'price': '£28.81', 'title': 'Burning'},
#  {'href': 'bossypants_883/index.html',
#   'price': '£49.46',
#   'title': 'Bossypants'},
#  {'href': 'bitch-planet-vol-1-extraordinary-machine-bitch-planet-collected-editions_882/index.html',
#   'price': '£37.92',
#   'title': 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))'},
#  {'href': 'avatar-the-last-airbender-smoke-and-shadow-part-3-smoke-and-shadow-3_881/index.html',
#   'price': '£28.09',
#   'title': 'Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)'},
#  {'href': 'algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html',
#   'price': '£30.81',
#   'title': 'Algorithms to Live By: The Computer Science of Human Decisions'},
#  {'href': 'a-world-of-flavor-your-gluten-free-passport_879/index.html',
#   'price': '£42.95',
#   'title': 'A World of Flavor: Your Gluten Free Passport'},
#  {'href': 'a-piece-of-sky-a-grain-of-rice-a-memoir-in-four-meditations_878/index.html',
#   'price': '£56.76',
#   'title': 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations'},
#  {'href': 'a-murder-in-time_877/index.html',
#   'price': '£16.64',
#   'title': 'A Murder in Time'},
#  {'href': 'a-flight-of-arrows-the-pathfinders-2_876/index.html',
#   'price': '£55.53',
#   'title': 'A Flight of Arrows (The Pathfinders #2)'},
#  {'href': 'a-fierce-and-subtle-poison_875/index.html',
#   'price': '£28.13',
#   'title': 'A Fierce and Subtle Poison'},
#  {'href': 'a-court-of-thorns-and-roses-a-court-of-thorns-and-roses-1_874/index.html',
#   'price': '£52.37',
#   'title': 'A Court of Thorns and Roses (A Court of Thorns and Roses #1)'},
#  {'href': 'unqualified-how-god-uses-broken-people-to-do-big-things_873/index.html',
#   'price': '£54.00',
#   'title': '(Un)Qualified: How God Uses Broken People to Do Big Things'},
#  {'href': 'you-are-what-you-love-the-spiritual-power-of-habit_872/index.html',
#   'price': '£21.87',
#   'title': 'You Are What You Love: The Spiritual Power of Habit'},
#  {'href': 'william-shakespeares-star-wars-verily-a-new-hope-william-shakespeares-star-wars-4_871/index.html',
#   'price': '£43.30',
#   'title': "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)"},
#  {'href': 'tuesday-nights-in-1980_870/index.html',
#   'price': '£21.04',
#   'title': 'Tuesday Nights in 1980'},
#  {'href': 'tracing-numbers-on-a-train_869/index.html',
#   'price': '£41.60',
#   'title': 'Tracing Numbers on a Train'},
#  {'href': 'throne-of-glass-throne-of-glass-1_868/index.html',
#   'price': '£35.07',
#   'title': 'Throne of Glass (Throne of Glass #1)'},
#  {'href': 'thomas-jefferson-and-the-tripoli-pirates-the-forgotten-war-that-changed-american-history_867/index.html',
#   'price': '£59.64',
#   'title': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History'},
#  {'href': 'thirteen-reasons-why_866/index.html',
#   'price': '£52.72',
#   'title': 'Thirteen Reasons Why'},
#  {'href': 'the-white-cat-and-the-monk-a-retelling-of-the-poem-pangur-ban_865/index.html',
#   'price': '£58.08',
#   'title': 'The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”'},
#  {'href': 'the-wedding-dress_864/index.html',
#   'price': '£24.12',
#   'title': 'The Wedding Dress'},
#  {'href': 'the-vacationers_863/index.html',
#   'price': '£42.15',
#   'title': 'The Vacationers'},
#  {'href': 'the-third-wave-an-entrepreneurs-vision-of-the-future_862/index.html',
#   'price': '£12.61',
#   'title': 'The Third Wave: An Entrepreneur’s Vision of the Future'},
#  {'href': 'the-stranger_861/index.html',
#   'price': '£17.44',
#   'title': 'The Stranger'},
#  {'href': 'the-shadow-hero-the-shadow-hero_860/index.html',
#   'price': '£33.14',
#   'title': 'The Shadow Hero (The Shadow Hero)'},
#  {'href': 'the-secret-the-secret-1_859/index.html',
#   'price': '£27.37',
#   'title': 'The Secret (The Secret #1)'},
#  {'href': 'the-regional-office-is-under-attack_858/index.html',
#   'price': '£51.36',
#   'title': 'The Regional Office Is Under Attack!'},
#  {'href': 'the-psychopath-test-a-journey-through-the-madness-industry_857/index.html',
#   'price': '£36.00',
#   'title': 'The Psychopath Test: A Journey Through the Madness Industry'},
#  {'href': 'the-project_856/index.html',
#   'price': '£10.65',
#   'title': 'The Project'},
#  {'href': 'the-power-of-now-a-guide-to-spiritual-enlightenment_855/index.html',
#   'price': '£43.54',
#   'title': 'The Power of Now: A Guide to Spiritual Enlightenment'},
#  {'href': 'the-omnivores-dilemma-a-natural-history-of-four-meals_854/index.html',
#   'price': '£38.21',
#   'title': "The Omnivore's Dilemma: A Natural History of Four Meals"},
#  {'href': 'the-nerdy-nummies-cookbook-sweet-treats-for-the-geek-in-all-of-us_853/index.html',
#   'price': '£37.34',
#   'title': 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us'},
#  {'href': 'the-murder-of-roger-ackroyd-hercule-poirot-4_852/index.html',
#   'price': '£44.10',
#   'title': 'The Murder of Roger Ackroyd (Hercule Poirot #4)'},
#  {'href': 'the-mistake-off-campus-2_851/index.html',
#   'price': '£43.29',
#   'title': 'The Mistake (Off-Campus #2)'},
#  {'href': 'the-matchmakers-playbook-wingmen-inc-1_850/index.html',
#   'price': '£55.85',
#   'title': "The Matchmaker's Playbook (Wingmen Inc. #1)"},
#  {'href': 'the-love-and-lemons-cookbook-an-apple-to-zucchini-celebration-of-impromptu-cooking_849/index.html',
#   'price': '£37.60',
#   'title': 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking'},
#  {'href': 'the-long-shadow-of-small-ghosts-murder-and-memory-in-an-american-city_848/index.html',
#   'price': '£10.97',
#   'title': 'The Long Shadow of Small Ghosts: Murder and Memory in an American City'},
#  {'href': 'the-kite-runner_847/index.html',
#   'price': '£41.82',
#   'title': 'The Kite Runner'},
#  {'href': 'the-house-by-the-lake_846/index.html',
#   'price': '£36.95',
#   'title': 'The House by the Lake'},
#  {'href': 'the-glittering-court-the-glittering-court-1_845/index.html',
#   'price': '£44.28',
#   'title': 'The Glittering Court (The Glittering Court #1)'},
#  {'href': 'the-girl-on-the-train_844/index.html',
#   'price': '£55.02',
#   'title': 'The Girl on the Train'},
#  {'href': 'the-genius-of-birds_843/index.html',
#   'price': '£17.24',
#   'title': 'The Genius of Birds'},
#  {'href': 'the-emerald-mystery_842/index.html',
#   'price': '£23.15',
#   'title': 'The Emerald Mystery'},
#  {'href': 'the-cookies-cups-cookbook-125-sweet-savory-recipes-reminding-you-to-always-eat-dessert-first_841/index.html',
#   'price': '£41.25',
#   'title': 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First'},
#  {'href': 'the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html',
#   'price': '£32.00',
#   'title': "The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs."},
#  {'href': 'the-artists-way-a-spiritual-path-to-higher-creativity_839/index.html',
#   'price': '£38.49',
#   'title': "The Artist's Way: A Spiritual Path to Higher Creativity"},
#  {'href': 'the-art-of-war_838/index.html',
#   'price': '£33.34',
#   'title': 'The Art of War'},
#  {'href': 'the-argonauts_837/index.html',
#   'price': '£10.93',
#   'title': 'The Argonauts'},
#  {'href': 'the-10-entrepreneur-live-your-startup-dream-without-quitting-your-day-job_836/index.html',
#   'price': '£27.55',
#   'title': 'The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job'},
#  {'href': 'suddenly-in-love-lake-haven-1_835/index.html',
#   'price': '£55.99',
#   'title': 'Suddenly in Love (Lake Haven #1)'},
#  {'href': 'something-more-than-this_834/index.html',
#   'price': '£16.24',
#   'title': 'Something More Than This'},
#  {'href': 'soft-apocalypse_833/index.html',
#   'price': '£26.12',
#   'title': 'Soft Apocalypse'},
#  {'href': 'so-youve-been-publicly-shamed_832/index.html',
#   'price': '£12.23',
#   'title': "So You've Been Publicly Shamed"},
#  {'href': 'shoe-dog-a-memoir-by-the-creator-of-nike_831/index.html',
#   'price': '£23.99',
#   'title': 'Shoe Dog: A Memoir by the Creator of NIKE'},
#  {'href': 'shobu-samurai-project-aryoku-3_830/index.html',
#   'price': '£29.06',
#   'title': 'Shobu Samurai, Project Aryoku (#3)'},
#  {'href': 'secrets-and-lace-fatal-hearts-1_829/index.html',
#   'price': '£20.27',
#   'title': 'Secrets and Lace (Fatal Hearts #1)'},
#  {'href': 'scarlett-epstein-hates-it-here_828/index.html',
#   'price': '£43.55',
#   'title': 'Scarlett Epstein Hates It Here'},
#  {'href': 'romero-and-juliet-a-tragic-tale-of-love-and-zombies_827/index.html',
#   'price': '£36.94',
#   'title': 'Romero and Juliet: A Tragic Tale of Love and Zombies'},
#  {'href': 'redeeming-love_826/index.html',
#   'price': '£20.47',
#   'title': 'Redeeming Love'},
#  {'href': 'poses-for-artists-volume-1-dynamic-and-sitting-poses-an-essential-reference-for-figure-drawing-and-the-human-form_825/index.html',
#   'price': '£41.06',
#   'title': 'Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form'},
#  {'href': 'poems-that-make-grown-women-cry_824/index.html',
#   'price': '£14.19',
#   'title': 'Poems That Make Grown Women Cry'},
#  {'href': 'nightingale-sing_823/index.html',
#   'price': '£38.28',
#   'title': 'Nightingale, Sing'},
#  {'href': 'night-sky-with-exit-wounds_822/index.html',
#   'price': '£41.05',
#   'title': 'Night Sky with Exit Wounds'},
#  {'href': 'mrs-houdini_821/index.html',
#   'price': '£30.25',
#   'title': 'Mrs. Houdini'},
#  {'href': 'modern-romance_820/index.html',
#   'price': '£28.26',
#   'title': 'Modern Romance'},
#  {'href': 'miss-peregrines-home-for-peculiar-children-miss-peregrines-peculiar-children-1_819/index.html',
#   'price': '£10.76',
#   'title': 'Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s Peculiar Children #1)'},
#  {'href': 'louisa-the-extraordinary-life-of-mrs-adams_818/index.html',
#   'price': '£16.85',
#   'title': 'Louisa: The Extraordinary Life of Mrs. Adams'},
#  {'href': 'little-red_817/index.html',
#   'price': '£13.47',
#   'title': 'Little Red'},
#  {'href': 'library-of-souls-miss-peregrines-peculiar-children-3_816/index.html',
#   'price': '£48.56',
#   'title': 'Library of Souls (Miss Peregrine’s Peculiar Children #3)'},
#  {'href': 'large-print-heart-of-the-pride_815/index.html',
#   'price': '£19.15',
#   'title': 'Large Print Heart of the Pride'},
#  {'href': 'i-had-a-nice-time-and-other-lies-how-to-find-love-sht-like-that_814/index.html',
#   'price': '£57.36',
#   'title': 'I Had a Nice Time And Other Lies...: How to find love & sh*t like that'},
#  {'href': 'hollow-city-miss-peregrines-peculiar-children-2_813/index.html',
#   'price': '£42.98',
#   'title': 'Hollow City (Miss Peregrine’s Peculiar Children #2)'},
#  {'href': 'grumbles_812/index.html', 'price': '£22.16', 'title': 'Grumbles'},
#  {'href': 'full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html',
#   'price': '£49.43',
#   'title': 'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond'},
#  {'href': 'frostbite-vampire-academy-2_810/index.html',
#   'price': '£29.99',
#   'title': 'Frostbite (Vampire Academy #2)'},
#  {'href': 'follow-you-home_809/index.html',
#   'price': '£21.36',
#   'title': 'Follow You Home'},
#  {'href': 'first-steps-for-new-christians-print-edition_808/index.html',
#   'price': '£29.00',
#   'title': 'First Steps for New Christians (Print Edition)'},
#  {'href': 'finders-keepers-bill-hodges-trilogy-2_807/index.html',
#   'price': '£53.53',
#   'title': 'Finders Keepers (Bill Hodges Trilogy #2)'},
#  {'href': 'fables-vol-1-legends-in-exile-fables-1_806/index.html',
#   'price': '£41.62',
#   'title': 'Fables, Vol. 1: Legends in Exile (Fables #1)'},
#  {'href': 'eureka-trivia-60_805/index.html',
#   'price': '£54.59',
#   'title': 'Eureka Trivia 6.0'},
#  {'href': 'drive-the-surprising-truth-about-what-motivates-us_804/index.html',
#   'price': '£34.95',
#   'title': 'Drive: The Surprising Truth About What Motivates Us'},
#  {'href': 'done-rubbed-out-reightman-bailey-1_803/index.html',
#   'price': '£37.72',
#   'title': 'Done Rubbed Out (Reightman & Bailey #1)'},
#  {'href': 'doing-it-over-most-likely-to-1_802/index.html',
#   'price': '£35.61',
#   'title': 'Doing It Over (Most Likely To #1)'},
#  {'href': 'deliciously-ella-every-day-quick-and-easy-recipes-for-gluten-free-snacks-packed-lunches-and-simple-meals_801/index.html',
#   'price': '£42.16',
#   'title': 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals'},
#  {'href': 'dark-notes_800/index.html',
#   'price': '£19.19',
#   'title': 'Dark Notes'},
#  {'href': 'daring-greatly-how-the-courage-to-be-vulnerable-transforms-the-way-we-live-love-parent-and-lead_799/index.html',
#   'price': '£19.43',
#   'title': 'Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead'},
#  {'href': 'close-to-you_798/index.html',
#   'price': '£49.46',
#   'title': 'Close to You'},
#  {'href': 'chasing-heaven-what-dying-taught-me-about-living_797/index.html',
#   'price': '£37.80',
#   'title': 'Chasing Heaven: What Dying Taught Me About Living'},
#  {'href': 'big-magic-creative-living-beyond-fear_796/index.html',
#   'price': '£30.80',
#   'title': 'Big Magic: Creative Living Beyond Fear'},
#  {'href': 'becoming-wise-an-inquiry-into-the-mystery-and-art-of-living_795/index.html',
#   'price': '£27.43',
#   'title': 'Becoming Wise: An Inquiry into the Mystery and Art of Living'},
#  {'href': 'beauty-restored-riley-family-legacy-novellas-3_794/index.html',
#   'price': '£11.11',
#   'title': 'Beauty Restored (Riley Family Legacy Novellas #3)'},
#  {'href': 'batman-the-long-halloween-batman_793/index.html',
#   'price': '£36.50',
#   'title': 'Batman: The Long Halloween (Batman)'},
#  {'href': 'batman-the-dark-knight-returns-batman_792/index.html',
#   'price': '£15.38',
#   'title': 'Batman: The Dark Knight Returns (Batman)'},
#  {'href': 'ayumis-violin_791/index.html',
#   'price': '£15.48',
#   'title': "Ayumi's Violin"},
#  {'href': 'anonymous_790/index.html', 'price': '£46.82', 'title': 'Anonymous'},
#  {'href': 'amy-meets-the-saints-and-sages_789/index.html',
#   'price': '£18.46',
#   'title': 'Amy Meets the Saints and Sages'},
#  {'href': 'amid-the-chaos_788/index.html',
#   'price': '£36.58',
#   'title': 'Amid the Chaos'},
#  {'href': 'amatus_787/index.html', 'price': '£50.54', 'title': 'Amatus'},
#  {'href': 'agnostic-a-spirited-manifesto_786/index.html',
#   'price': '£12.51',
#   'title': 'Agnostic: A Spirited Manifesto'},
#  {'href': 'zealot-the-life-and-times-of-jesus-of-nazareth_785/index.html',
#   'price': '£24.70',
#   'title': 'Zealot: The Life and Times of Jesus of Nazareth'},
#  {'href': 'you-you-1_784/index.html',
#   'price': '£43.61',
#   'title': 'You (You #1)'},
#  {'href': 'wonder-woman-earth-one-volume-one-wonder-woman-earth-one-1_783/index.html',
#   'price': '£37.34',
#   'title': 'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)'},
#  {'href': 'wild-swans_782/index.html',
#   'price': '£14.36',
#   'title': 'Wild Swans'},
#  {'href': 'why-the-right-went-wrong-conservatism-from-goldwater-to-the-tea-party-and-beyond_781/index.html',
#   'price': '£52.65',
#   'title': 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond'},
#  {'href': 'whole-lotta-creativity-going-on-60-fun-and-unusual-exercises-to-awaken-and-strengthen-your-creativity_780/index.html',
#   'price': '£38.20',
#   'title': 'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity'},
#  {'href': 'whats-it-like-in-space-stories-from-astronauts-whove-been-there_779/index.html',
#   'price': '£19.60',
#   'title': "What's It Like in Space?: Stories from Astronauts Who've Been There"},
#  {'href': 'we-are-robin-vol-1-the-vigilante-business-we-are-robin-1_778/index.html',
#   'price': '£53.90',
#   'title': 'We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)'},
#  {'href': 'walt-disneys-alice-in-wonderland_777/index.html',
#   'price': '£12.96',
#   'title': "Walt Disney's Alice in Wonderland"},
#  {'href': 'v-for-vendetta-v-for-vendetta-complete_776/index.html',
#   'price': '£37.10',
#   'title': 'V for Vendetta (V for Vendetta Complete)'},
#  {'href': 'until-friday-night-the-field-party-1_775/index.html',
#   'price': '£46.31',
#   'title': 'Until Friday Night (The Field Party #1)'},
#  {'href': 'unbroken-a-world-war-ii-story-of-survival-resilience-and-redemption_774/index.html',
#   'price': '£45.95',
#   'title': 'Unbroken: A World War II Story of Survival, Resilience, and Redemption'},
#  {'href': 'twenty-yawns_773/index.html',
#   'price': '£22.08',
#   'title': 'Twenty Yawns'},
#  {'href': 'through-the-woods_772/index.html',
#   'price': '£25.38',
#   'title': 'Through the Woods'},
#  {'href': 'this-is-where-it-ends_771/index.html',
#   'price': '£27.12',
#   'title': 'This Is Where It Ends'},
#  {'href': 'the-year-of-magical-thinking_770/index.html',
#   'price': '£43.04',
#   'title': 'The Year of Magical Thinking'},
#  {'href': 'the-wright-brothers_769/index.html',
#   'price': '£56.80',
#   'title': 'The Wright Brothers'},
#  {'href': 'the-white-queen-the-cousins-war-1_768/index.html',
#   'price': '£25.91',
#   'title': "The White Queen (The Cousins' War #1)"},
#  {'href': 'the-wedding-pact-the-omalleys-2_767/index.html',
#   'price': '£32.61',
#   'title': "The Wedding Pact (The O'Malleys #2)"},
#  {'href': 'the-time-keeper_766/index.html',
#   'price': '£27.88',
#   'title': 'The Time Keeper'},
#  {'href': 'the-testament-of-mary_765/index.html',
#   'price': '£52.67',
#   'title': 'The Testament of Mary'},
#  {'href': 'the-star-touched-queen_764/index.html',
#   'price': '£46.02',
#   'title': 'The Star-Touched Queen'},
#  {'href': 'the-songs-of-the-gods_763/index.html',
#   'price': '£44.48',
#   'title': 'The Songs of the Gods'},
#  {'href': 'the-song-of-achilles_762/index.html',
#   'price': '£37.40',
#   'title': 'The Song of Achilles'},
#  {'href': 'the-rosie-project-don-tillman-1_761/index.html',
#   'price': '£54.04',
#   'title': 'The Rosie Project (Don Tillman #1)'},
#  {'href': 'the-power-of-habit-why-we-do-what-we-do-in-life-and-business_760/index.html',
#   'price': '£16.88',
#   'title': 'The Power of Habit: Why We Do What We Do in Life and Business'},
#  {'href': 'the-marriage-of-opposites_759/index.html',
#   'price': '£28.08',
#   'title': 'The Marriage of Opposites'},
#  {'href': 'the-lucifer-effect-understanding-how-good-people-turn-evil_758/index.html',
#   'price': '£10.40',
#   'title': 'The Lucifer Effect: Understanding How Good People Turn Evil'},
#  {'href': 'the-long-haul-diary-of-a-wimpy-kid-9_757/index.html',
#   'price': '£44.07',
#   'title': 'The Long Haul (Diary of a Wimpy Kid #9)'},
#  {'href': 'the-loney_756/index.html', 'price': '£23.40', 'title': 'The Loney'},
#  {'href': 'the-literature-book-big-ideas-simply-explained_755/index.html',
#   'price': '£17.43',
#   'title': 'The Literature Book (Big Ideas Simply Explained)'},
#  {'href': 'the-last-mile-amos-decker-2_754/index.html',
#   'price': '£54.21',
#   'title': 'The Last Mile (Amos Decker #2)'},
#  {'href': 'the-immortal-life-of-henrietta-lacks_753/index.html',
#   'price': '£40.67',
#   'title': 'The Immortal Life of Henrietta Lacks'},
#  {'href': 'the-hidden-oracle-the-trials-of-apollo-1_752/index.html',
#   'price': '£52.26',
#   'title': 'The Hidden Oracle (The Trials of Apollo #1)'},
#  {'href': 'the-help-yourself-cookbook-for-kids-60-easy-plant-based-recipes-kids-can-make-to-stay-healthy-and-save-the-earth_751/index.html',
#   'price': '£28.77',
#   'title': 'The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth'},
#  {'href': 'the-guilty-will-robie-4_750/index.html',
#   'price': '£13.82',
#   'title': 'The Guilty (Will Robie #4)'},
#  {'href': 'the-first-hostage-jb-collins-2_749/index.html',
#   'price': '£25.85',
#   'title': 'The First Hostage (J.B. Collins #2)'},
#  {'href': 'the-dovekeepers_748/index.html',
#   'price': '£48.78',
#   'title': 'The Dovekeepers'},
#  {'href': 'the-darkest-lie_747/index.html',
#   'price': '£35.35',
#   'title': 'The Darkest Lie'},
#  {'href': 'the-bane-chronicles-the-bane-chronicles-1-11_746/index.html',
#   'price': '£44.73',
#   'title': 'The Bane Chronicles (The Bane Chronicles #1-11)'},
#  {'href': 'the-bad-ass-librarians-of-timbuktu-and-their-race-to-save-the-worlds-most-precious-manuscripts_745/index.html',
#   'price': '£15.77',
#   'title': 'The Bad-Ass Librarians of Timbuktu: And Their Race to Save the World’s Most Precious Manuscripts'},
#  {'href': 'the-14th-colony-cotton-malone-11_744/index.html',
#   'price': '£39.24',
#   'title': 'The 14th Colony (Cotton Malone #11)'},
#  {'href': 'that-darkness-gardiner-and-renner-1_743/index.html',
#   'price': '£13.92',
#   'title': 'That Darkness (Gardiner and Renner #1)'},
#  {'href': 'tastes-like-fear-di-marnie-rome-3_742/index.html',
#   'price': '£10.69',
#   'title': 'Tastes Like Fear (DI Marnie Rome #3)'},
#  {'href': 'take-me-with-you_741/index.html',
#   'price': '£45.21',
#   'title': 'Take Me with You'},
#  {'href': 'swell-a-year-of-waves_740/index.html',
#   'price': '£45.58',
#   'title': 'Swell: A Year of Waves'},
#  {'href': 'superman-vol-1-before-truth-superman-by-gene-luen-yang-1_739/index.html',
#   'price': '£11.89',
#   'title': 'Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)'},
#  {'href': 'still-life-with-bread-crumbs_738/index.html',
#   'price': '£26.41',
#   'title': 'Still Life with Bread Crumbs'},
#  {'href': 'steve-jobs_737/index.html',
#   'price': '£39.50',
#   'title': 'Steve Jobs'},
#  {'href': 'sorting-the-beef-from-the-bull-the-science-of-food-fraud-forensics_736/index.html',
#   'price': '£44.74',
#   'title': 'Sorting the Beef from the Bull: The Science of Food Fraud Forensics'},
#  {'href': 'someone-like-you-the-harrisons-2_735/index.html',
#   'price': '£52.79',
#   'title': 'Someone Like You (The Harrisons #2)'},
#  {'href': 'so-cute-it-hurts-vol-6-so-cute-it-hurts-6_734/index.html',
#   'price': '£35.43',
#   'title': 'So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)'},
#  {'href': 'shtum_733/index.html', 'price': '£55.84', 'title': 'Shtum'},
#  {'href': 'see-america-a-celebration-of-our-national-parks-treasured-sites_732/index.html',
#   'price': '£48.87',
#   'title': 'See America: A Celebration of Our National Parks & Treasured Sites'},
#  {'href': 'salt_731/index.html', 'price': '£46.78', 'title': 'salt.'},
#  {'href': 'robin-war_730/index.html', 'price': '£47.82', 'title': 'Robin War'},
#  {'href': 'red-hoodarsenal-vol-1-open-for-business-red-hoodarsenal-1_729/index.html',
#   'price': '£25.48',
#   'title': 'Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)'},
#  {'href': 'rain-fish_728/index.html', 'price': '£23.57', 'title': 'Rain Fish'},
#  {'href': 'quarter-life-poetry-poems-for-the-young-broke-and-hangry_727/index.html',
#   'price': '£50.89',
#   'title': 'Quarter Life Poetry: Poems for the Young, Broke and Hangry'},
#  {'href': 'pet-sematary_726/index.html',
#   'price': '£10.56',
#   'title': 'Pet Sematary'},
#  {'href': 'overload-how-to-unplug-unwind-and-unleash-yourself-from-the-pressure-of-stress_725/index.html',
#   'price': '£52.15',
#   'title': 'Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress'},
#  {'href': 'once-was-a-time_724/index.html',
#   'price': '£18.28',
#   'title': 'Once Was a Time'},
#  {'href': 'old-school-diary-of-a-wimpy-kid-10_723/index.html',
#   'price': '£11.83',
#   'title': 'Old School (Diary of a Wimpy Kid #10)'},
#  {'href': 'no-dream-is-too-high-life-lessons-from-a-man-who-walked-on-the-moon_722/index.html',
#   'price': '£21.95',
#   'title': 'No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon'},
#  {'href': 'naruto-3-in-1-edition-vol-14-includes-vols-40-41-42-naruto-omnibus-14_721/index.html',
#   'price': '£38.39',
#   'title': 'Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)'},
#  {'href': 'my-name-is-lucy-barton_720/index.html',
#   'price': '£41.56',
#   'title': 'My Name Is Lucy Barton'},
#  {'href': 'my-mrs-brown_719/index.html',
#   'price': '£24.48',
#   'title': 'My Mrs. Brown'},
#  {'href': 'my-kind-of-crazy_718/index.html',
#   'price': '£40.36',
#   'title': 'My Kind of Crazy'},
#  {'href': 'mr-mercedes-bill-hodges-trilogy-1_717/index.html',
#   'price': '£28.90',
#   'title': 'Mr. Mercedes (Bill Hodges Trilogy #1)'},
#  {'href': 'more-than-music-chasing-the-dream-1_716/index.html',
#   'price': '£37.61',
#   'title': 'More Than Music (Chasing the Dream #1)'},
#  {'href': 'made-to-stick-why-some-ideas-survive-and-others-die_715/index.html',
#   'price': '£38.85',
#   'title': 'Made to Stick: Why Some Ideas Survive and Others Die'},
#  {'href': 'luis-paints-the-world_714/index.html',
#   'price': '£53.95',
#   'title': 'Luis Paints the World'},
#  {'href': 'luckiest-girl-alive_713/index.html',
#   'price': '£49.83',
#   'title': 'Luckiest Girl Alive'},
#  {'href': 'lowriders-to-the-center-of-the-earth-lowriders-in-space-2_712/index.html',
#   'price': '£51.51',
#   'title': 'Lowriders to the Center of the Earth (Lowriders in Space #2)'},
#  {'href': 'love-is-a-mix-tape-music-1_711/index.html',
#   'price': '£18.03',
#   'title': 'Love Is a Mix Tape (Music #1)'},
#  {'href': 'looking-for-lovely-collecting-the-moments-that-matter_710/index.html',
#   'price': '£29.14',
#   'title': 'Looking for Lovely: Collecting the Moments that Matter'},
#  {'href': 'living-leadership-by-insight-a-good-leader-achieves-a-great-leader-builds-monuments_709/index.html',
#   'price': '£46.91',
#   'title': 'Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments'},
#  {'href': 'let-it-out-a-journey-through-journaling_708/index.html',
#   'price': '£26.79',
#   'title': 'Let It Out: A Journey Through Journaling'},
#  {'href': 'lady-midnight-the-dark-artifices-1_707/index.html',
#   'price': '£16.28',
#   'title': 'Lady Midnight (The Dark Artifices #1)'},
#  {'href': 'its-all-easy-healthy-delicious-weeknight-meals-in-under-30-minutes_706/index.html',
#   'price': '£19.55',
#   'title': "It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes"},
#  {'href': 'island-of-dragons-unwanteds-7_705/index.html',
#   'price': '£29.65',
#   'title': 'Island of Dragons (Unwanteds #7)'},
#  {'href': 'i-know-what-im-doing-and-other-lies-i-tell-myself-dispatches-from-a-life-under-construction_704/index.html',
#   'price': '£25.98',
#   'title': "I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction"},
#  {'href': 'i-am-pilgrim-pilgrim-1_703/index.html',
#   'price': '£10.60',
#   'title': 'I Am Pilgrim (Pilgrim #1)'},
#  {'href': 'hyperbole-and-a-half-unfortunate-situations-flawed-coping-mechanisms-mayhem-and-other-things-that-happened_702/index.html',
#   'price': '£14.75',
#   'title': 'Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened'},
#  {'href': 'hush-hush-hush-hush-1_701/index.html',
#   'price': '£47.02',
#   'title': 'Hush, Hush (Hush, Hush #1)'},
#  {'href': 'hold-your-breath-search-and-rescue-1_700/index.html',
#   'price': '£28.82',
#   'title': 'Hold Your Breath (Search and Rescue #1)'},
#  {'href': 'hamilton-the-revolution_699/index.html',
#   'price': '£58.79',
#   'title': 'Hamilton: The Revolution'},
#  {'href': 'greek-mythic-history_698/index.html',
#   'price': '£10.23',
#   'title': 'Greek Mythic History'},
#  {'href': 'god-the-most-unpleasant-character-in-all-fiction_697/index.html',
#   'price': '£30.03',
#   'title': 'God: The Most Unpleasant Character in All Fiction'},
#  {'href': 'glory-over-everything-beyond-the-kitchen-house_696/index.html',
#   'price': '£45.84',
#   'title': 'Glory over Everything: Beyond The Kitchen House'},
#  {'href': 'feathers-displays-of-brilliant-plumage_695/index.html',
#   'price': '£49.05',
#   'title': 'Feathers: Displays of Brilliant Plumage'},
#  {'href': 'far-away-places-on-the-brink-of-change-seven-continents-twenty-five-years_694/index.html',
#   'price': '£15.06',
#   'title': 'Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years'},
#  {'href': 'every-last-word_693/index.html',
#   'price': '£46.47',
#   'title': 'Every Last Word'},
#  {'href': 'eligible-the-austen-project-4_692/index.html',
#   'price': '£27.09',
#   'title': 'Eligible (The Austen Project #4)'},
#  {'href': 'el-deafo_691/index.html', 'price': '£57.62', 'title': 'El Deafo'},
#  {'href': 'eight-hundred-grapes_690/index.html',
#   'price': '£14.39',
#   'title': 'Eight Hundred Grapes'},
#  {'href': 'eaternity-more-than-150-deliciously-easy-vegan-recipes-for-a-long-healthy-satisfied-joyful-life_689/index.html',
#   'price': '£51.75',
#   'title': 'Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life'},
#  {'href': 'eat-fat-get-thin_688/index.html',
#   'price': '£54.07',
#   'title': 'Eat Fat, Get Thin'},
#  {'href': 'dont-get-caught_687/index.html',
#   'price': '£55.35',
#   'title': "Don't Get Caught"},
#  {'href': 'doctor-sleep-the-shining-2_686/index.html',
#   'price': '£40.12',
#   'title': 'Doctor Sleep (The Shining #2)'},
#  {'href': 'demigods-magicians-percy-and-annabeth-meet-the-kanes-percy-jackson-kane-chronicles-crossover-1-3_685/index.html',
#   'price': '£37.51',
#   'title': 'Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)'},
#  {'href': 'dear-mr-knightley_684/index.html',
#   'price': '£11.21',
#   'title': 'Dear Mr. Knightley'},
#  {'href': 'daily-fantasy-sports_683/index.html',
#   'price': '£36.58',
#   'title': 'Daily Fantasy Sports'},
#  {'href': 'crazy-love-overwhelmed-by-a-relentless-god_682/index.html',
#   'price': '£47.72',
#   'title': 'Crazy Love: Overwhelmed by a Relentless God'},
#  {'href': 'cometh-the-hour-the-clifton-chronicles-6_681/index.html',
#   'price': '£25.01',
#   'title': 'Cometh the Hour (The Clifton Chronicles #6)'},
#  {'href': 'code-name-verity-code-name-verity-1_680/index.html',
#   'price': '£22.13',
#   'title': 'Code Name Verity (Code Name Verity #1)'},
#  {'href': 'clockwork-angel-the-infernal-devices-1_679/index.html',
#   'price': '£44.14',
#   'title': 'Clockwork Angel (The Infernal Devices #1)'},
#  {'href': 'city-of-glass-the-mortal-instruments-3_678/index.html',
#   'price': '£56.02',
# ...
#   'price': '£20.79',
#   'title': 'Between Shades of Gray'},
#  {'href': 'best-of-my-love-fools-gold-20_127/index.html',
#   'price': '£27.41',
#   'title': "Best of My Love (Fool's Gold #20)"},
#  {'href': 'beowulf_126/index.html', 'price': '£38.35', 'title': 'Beowulf'},
#  {'href': 'beautiful-creatures-caster-chronicles-1_125/index.html',
#   'price': '£21.55',
#   'title': 'Beautiful Creatures (Caster Chronicles #1)'},
#  {'href': 'awkward_124/index.html', 'price': '£38.02', 'title': 'Awkward'},
#  {'href': 'ash_123/index.html', 'price': '£22.06', 'title': 'Ash'},
#  {'href': 'are-we-there-yet_122/index.html',
#   'price': '£10.66',
#   'title': 'Are We There Yet?'},
#  {'href': 'are-we-smart-enough-to-know-how-smart-animals-are_121/index.html',
#   'price': '£56.58',
#   'title': 'Are We Smart Enough to Know How Smart Animals Are?'},
#  {'href': 'annie-on-my-mind_120/index.html',
#   'price': '£36.83',
#   'title': 'Annie on My Mind'},
#  {'href': 'and-then-there-were-none_119/index.html',
#   'price': '£35.01',
#   'title': 'And Then There Were None'},
#  {'href': 'a-walk-in-the-woods-rediscovering-america-on-the-appalachian-trail_118/index.html',
#   'price': '£30.48',
#   'title': 'A Walk in the Woods: Rediscovering America on the Appalachian Trail'},
#  {'href': 'a-visit-from-the-goon-squad_117/index.html',
#   'price': '£14.08',
#   'title': 'A Visit from the Goon Squad'},
#  {'href': 'a-storm-of-swords-a-song-of-ice-and-fire-3_116/index.html',
#   'price': '£31.22',
#   'title': 'A Storm of Swords (A Song of Ice and Fire #3)'},
#  {'href': 'a-heartbreaking-work-of-staggering-genius_115/index.html',
#   'price': '£54.29',
#   'title': 'A Heartbreaking Work of Staggering Genius'},
#  {'href': '8-keys-to-mental-health-through-exercise_114/index.html',
#   'price': '£31.04',
#   'title': '8 Keys to Mental Health Through Exercise'},
#  {'href': 'girlboss_113/index.html', 'price': '£50.96', 'title': '#GIRLBOSS'},
#  {'href': 'the-suffragettes-little-black-classics-96_112/index.html',
#   'price': '£11.89',
#   'title': 'The Suffragettes (Little Black Classics, #96)'},
#  {'href': 'the-sense-of-an-ending_111/index.html',
#   'price': '£31.38',
#   'title': 'The Sense of an Ending'},
#  {'href': 'the-sandman-vol-2-the-dolls-house-the-sandman-volumes-2_110/index.html',
#   'price': '£54.81',
#   'title': "The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)"},
#  {'href': 'the-course-of-love_109/index.html',
#   'price': '£16.78',
#   'title': 'The Course of Love'},
#  {'href': 'sugar-rush-offensive-line-2_108/index.html',
#   'price': '£24.42',
#   'title': 'Sugar Rush (Offensive Line #2)'},
#  {'href': 'saga-volume-2-saga-collected-editions-2_107/index.html',
#   'price': '£11.75',
#   'title': 'Saga, Volume 2 (Saga (Collected Editions) #2)'},
#  {'href': 'run-spot-run-the-ethics-of-keeping-pets_106/index.html',
#   'price': '£20.02',
#   'title': 'Run, Spot, Run: The Ethics of Keeping Pets'},
#  {'href': 'new-moon-twilight-2_105/index.html',
#   'price': '£12.86',
#   'title': 'New Moon (Twilight #2)'},
#  {'href': 'life_104/index.html', 'price': '£31.58', 'title': 'Life'},
#  {'href': 'kindle-paperwhite-users-guide_103/index.html',
#   'price': '£34.00',
#   'title': "Kindle Paperwhite User's Guide"},
#  {'href': 'h-is-for-hawk_102/index.html',
#   'price': '£57.42',
#   'title': 'H is for Hawk'},
#  {'href': 'girl-online-on-tour-girl-online-2_101/index.html',
#   'price': '£53.47',
#   'title': 'Girl Online On Tour (Girl Online #2)'},
#  {'href': 'fruits-basket-vol-2-fruits-basket-2_100/index.html',
#   'price': '£11.64',
#   'title': 'Fruits Basket, Vol. 2 (Fruits Basket #2)'},
#  {'href': 'diary-of-a-minecraft-zombie-book-1-a-scare-of-a-dare-an-unofficial-minecraft-book_99/index.html',
#   'price': '£52.88',
#   'title': 'Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)'},
#  {'href': 'y-the-last-man-vol-1-unmanned-y-the-last-man-1_98/index.html',
#   'price': '£18.51',
#   'title': 'Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)'},
#  {'href': 'while-you-were-mine_97/index.html',
#   'price': '£41.32',
#   'title': 'While You Were Mine'},
#  {'href': 'where-lightning-strikes-bleeding-stars-3_96/index.html',
#   'price': '£39.77',
#   'title': 'Where Lightning Strikes (Bleeding Stars #3)'},
#  {'href': 'when-im-gone_95/index.html',
#   'price': '£51.96',
#   'title': "When I'm Gone"},
#  {'href': 'ways-of-seeing_94/index.html',
#   'price': '£39.51',
#   'title': 'Ways of Seeing'},
#  {'href': 'vampire-knight-vol-1-vampire-knight-1_93/index.html',
#   'price': '£15.40',
#   'title': 'Vampire Knight, Vol. 1 (Vampire Knight #1)'},
#  {'href': 'vampire-girl-vampire-girl-1_92/index.html',
#   'price': '£53.82',
#   'title': 'Vampire Girl (Vampire Girl #1)'},
#  {'href': 'twenty-love-poems-and-a-song-of-despair_91/index.html',
#   'price': '£30.95',
#   'title': 'Twenty Love Poems and a Song of Despair'},
#  {'href': 'travels-with-charley-in-search-of-america_90/index.html',
#   'price': '£57.82',
#   'title': 'Travels with Charley: In Search of America'},
#  {'href': 'three-wishes-river-of-time-california-1_89/index.html',
#   'price': '£44.18',
#   'title': 'Three Wishes (River of Time: California #1)'},
#  {'href': 'this-one-moment-pushing-limits-1_88/index.html',
#   'price': '£48.71',
#   'title': 'This One Moment (Pushing Limits #1)'},
#  {'href': 'the-zombie-room_87/index.html',
#   'price': '£19.69',
#   'title': 'The Zombie Room'},
#  {'href': 'the-wicked-the-divine-vol-1-the-faust-act-the-wicked-the-divine_86/index.html',
#   'price': '£36.52',
#   'title': 'The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)'},
#  {'href': 'the-tumor_85/index.html', 'price': '£41.56', 'title': 'The Tumor'},
#  {'href': 'the-story-of-hong-gildong_84/index.html',
#   'price': '£43.19',
#   'title': 'The Story of Hong Gildong'},
#  {'href': 'the-silent-wife_83/index.html',
#   'price': '£12.34',
#   'title': 'The Silent Wife'},
#  {'href': 'the-silent-twin-detective-jennifer-knight-3_82/index.html',
#   'price': '£36.25',
#   'title': 'The Silent Twin (Detective Jennifer Knight #3)'},
#  {'href': 'the-selfish-gene_81/index.html',
#   'price': '£29.45',
#   'title': 'The Selfish Gene'},
#  {'href': 'the-secret-healer_80/index.html',
#   'price': '£34.56',
#   'title': 'The Secret Healer'},
#  {'href': 'the-sandman-vol-1-preludes-and-nocturnes-the-sandman-volumes-1_79/index.html',
#   'price': '£54.12',
#   'title': 'The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)'},
#  {'href': 'the-republic_78/index.html',
#   'price': '£33.78',
#   'title': 'The Republic'},
#  {'href': 'the-odyssey_77/index.html',
#   'price': '£29.64',
#   'title': 'The Odyssey'},
#  {'href': 'the-no-1-ladies-detective-agency-no-1-ladies-detective-agency-1_76/index.html',
#   'price': '£57.70',
#   'title': "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)"},
#  {'href': 'the-nicomachean-ethics_75/index.html',
#   'price': '£36.34',
#   'title': 'The Nicomachean Ethics'},
#  {'href': 'the-name-of-the-wind-the-kingkiller-chronicle-1_74/index.html',
#   'price': '£50.59',
#   'title': 'The Name of the Wind (The Kingkiller Chronicle #1)'},
#  {'href': 'the-mirror-the-maze-the-wrath-and-the-dawn-15_73/index.html',
#   'price': '£29.38',
#   'title': 'The Mirror & the Maze (The Wrath and the Dawn #1.5)'},
#  {'href': 'the-little-prince_72/index.html',
#   'price': '£45.42',
#   'title': 'The Little Prince'},
#  {'href': 'the-light-of-the-fireflies_71/index.html',
#   'price': '£54.43',
#   'title': 'The Light of the Fireflies'},
#  {'href': 'the-last-girl-the-dominion-trilogy-1_70/index.html',
#   'price': '£36.26',
#   'title': 'The Last Girl (The Dominion Trilogy #1)'},
#  {'href': 'the-iliad_69/index.html', 'price': '£16.16', 'title': 'The Iliad'},
#  {'href': 'the-hook-up-game-on-1_68/index.html',
#   'price': '£36.29',
#   'title': 'The Hook Up (Game On #1)'},
#  {'href': 'the-haters_67/index.html',
#   'price': '£27.89',
#   'title': 'The Haters'},
#  {'href': 'the-girl-you-lost_66/index.html',
#   'price': '£12.29',
#   'title': 'The Girl You Lost'},
#  {'href': 'the-girl-in-the-ice-dci-erika-foster-1_65/index.html',
#   'price': '£15.85',
#   'title': 'The Girl In The Ice (DCI Erika Foster #1)'},
#  {'href': 'the-end-of-the-jesus-era-an-investigation-1_64/index.html',
#   'price': '£14.40',
#   'title': 'The End of the Jesus Era (An Investigation #1)'},
#  {'href': 'the-edge-of-reason-bridget-jones-2_63/index.html',
#   'price': '£19.18',
#   'title': 'The Edge of Reason (Bridget Jones #2)'},
#  {'href': 'the-complete-maus-maus-1-2_62/index.html',
#   'price': '£10.64',
#   'title': 'The Complete Maus (Maus #1-2)'},
#  {'href': 'the-communist-manifesto_61/index.html',
#   'price': '£14.76',
#   'title': 'The Communist Manifesto'},
#  {'href': 'the-bhagavad-gita_60/index.html',
#   'price': '£57.49',
#   'title': 'The Bhagavad Gita'},
#  {'href': 'the-bette-davis-club_59/index.html',
#   'price': '£30.66',
#   'title': 'The Bette Davis Club'},
#  {'href': 'the-art-of-not-breathing_58/index.html',
#   'price': '£40.83',
#   'title': 'The Art of Not Breathing'},
#  {'href': 'taking-shots-assassins-1_57/index.html',
#   'price': '£18.88',
#   'title': 'Taking Shots (Assassins #1)'},
#  {'href': 'starlark_56/index.html', 'price': '£25.83', 'title': 'Starlark'},
#  {'href': 'skip-beat-vol-01-skip-beat-1_55/index.html',
#   'price': '£42.12',
#   'title': 'Skip Beat!, Vol. 01 (Skip Beat! #1)'},
#  {'href': 'sister-sable-the-mad-queen-1_54/index.html',
#   'price': '£13.33',
#   'title': 'Sister Sable (The Mad Queen #1)'},
#  {'href': 'shatter-me-shatter-me-1_53/index.html',
#   'price': '£42.40',
#   'title': 'Shatter Me (Shatter Me #1)'},
#  {'href': 'shameless_52/index.html', 'price': '£58.35', 'title': 'Shameless'},
#  {'href': 'shadow-rites-jane-yellowrock-10_51/index.html',
#   'price': '£21.72',
#   'title': 'Shadow Rites (Jane Yellowrock #10)'},
#  {'href': 'settling-the-score-the-summer-games-1_50/index.html',
#   'price': '£44.91',
#   'title': 'Settling the Score (The Summer Games #1)'},
#  {'href': 'sense-and-sensibility_49/index.html',
#   'price': '£37.46',
#   'title': 'Sense and Sensibility'},
#  {'href': 'saga-volume-1-saga-collected-editions-1_48/index.html',
#   'price': '£28.48',
#   'title': 'Saga, Volume 1 (Saga (Collected Editions) #1)'},
#  {'href': 'rhythm-chord-malykhin_47/index.html',
#   'price': '£28.34',
#   'title': 'Rhythm, Chord & Malykhin'},
#  {'href': 'rat-queens-vol-1-sass-sorcery-rat-queens-collected-editions-1-5_46/index.html',
#   'price': '£46.96',
#   'title': 'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)'},
#  {'href': 'paradise-lost-paradise-1_45/index.html',
#   'price': '£24.96',
#   'title': 'Paradise Lost (Paradise #1)'},
#  {'href': 'paper-girls-vol-1-paper-girls-1-5_44/index.html',
#   'price': '£21.71',
#   'title': 'Paper Girls, Vol. 1 (Paper Girls #1-5)'},
#  {'href': 'ouran-high-school-host-club-vol-1-ouran-high-school-host-club-1_43/index.html',
#   'price': '£29.87',
#   'title': 'Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)'},
#  {'href': 'origins-alphas-05_42/index.html',
#   'price': '£28.99',
#   'title': 'Origins (Alphas 0.5)'},
#  {'href': 'one-second-seven-7_41/index.html',
#   'price': '£52.94',
#   'title': 'One Second (Seven #7)'},
#  {'href': 'on-the-road-duluoz-legend_40/index.html',
#   'price': '£32.36',
#   'title': 'On the Road (Duluoz Legend)'},
#  {'href': 'old-records-never-die-one-mans-quest-for-his-vinyl-and-his-past_39/index.html',
#   'price': '£55.66',
#   'title': "Old Records Never Die: One Man's Quest for His Vinyl and His Past"},
#  {'href': 'off-sides-off-1_38/index.html',
#   'price': '£39.45',
#   'title': 'Off Sides (Off #1)'},
#  {'href': 'of-mice-and-men_37/index.html',
#   'price': '£47.11',
#   'title': 'Of Mice and Men'},
#  {'href': 'myriad-prentor-1_36/index.html',
#   'price': '£58.75',
#   'title': 'Myriad (Prentor #1)'},
#  {'href': 'my-perfect-mistake-over-the-top-1_35/index.html',
#   'price': '£38.92',
#   'title': 'My Perfect Mistake (Over the Top #1)'},
#  {'href': 'ms-marvel-vol-1-no-normal-ms-marvel-2014-2015-1_34/index.html',
#   'price': '£39.39',
#   'title': 'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)'},
#  {'href': 'meditations_33/index.html',
#   'price': '£25.89',
#   'title': 'Meditations'},
#  {'href': 'matilda_32/index.html', 'price': '£28.34', 'title': 'Matilda'},
#  {'href': 'lost-among-the-living_31/index.html',
#   'price': '£27.70',
#   'title': 'Lost Among the Living'},
#  {'href': 'lord-of-the-flies_30/index.html',
#   'price': '£24.89',
#   'title': 'Lord of the Flies'},
#  {'href': 'listen-to-me-fusion-1_29/index.html',
#   'price': '£58.99',
#   'title': 'Listen to Me (Fusion #1)'},
#  {'href': 'kitchens-of-the-great-midwest_28/index.html',
#   'price': '£57.20',
#   'title': 'Kitchens of the Great Midwest'},
#  {'href': 'jane-eyre_27/index.html', 'price': '£38.43', 'title': 'Jane Eyre'},
#  {'href': 'imperfect-harmony_26/index.html',
#   'price': '£34.74',
#   'title': 'Imperfect Harmony'},
#  {'href': 'icing-aces-hockey-2_25/index.html',
#   'price': '£40.44',
#   'title': 'Icing (Aces Hockey #2)'},
#  {'href': 'hawkeye-vol-1-my-life-as-a-weapon-hawkeye-1_24/index.html',
#   'price': '£45.24',
#   'title': 'Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)'},
#  {'href': 'having-the-barbarians-baby-ice-planet-barbarians-75_23/index.html',
#   'price': '£34.96',
#   'title': "Having the Barbarian's Baby (Ice Planet Barbarians #7.5)"},
#  {'href': 'giant-days-vol-1-giant-days-1-4_22/index.html',
#   'price': '£56.76',
#   'title': 'Giant Days, Vol. 1 (Giant Days #1-4)'},
#  {'href': 'fruits-basket-vol-1-fruits-basket-1_21/index.html',
#   'price': '£40.28',
#   'title': 'Fruits Basket, Vol. 1 (Fruits Basket #1)'},
#  {'href': 'frankenstein_20/index.html',
#   'price': '£38.00',
#   'title': 'Frankenstein'},
#  {'href': 'forever-rockers-the-rocker-12_19/index.html',
#   'price': '£28.80',
#   'title': 'Forever Rockers (The Rocker #12)'},
#  {'href': 'fighting-fate-fighting-6_18/index.html',
#   'price': '£39.24',
#   'title': 'Fighting Fate (Fighting #6)'},
#  {'href': 'emma_17/index.html', 'price': '£32.93', 'title': 'Emma'},
#  {'href': 'eat-pray-love_16/index.html',
#   'price': '£51.32',
#   'title': 'Eat, Pray, Love'},
#  {'href': 'deep-under-walker-security-1_15/index.html',
#   'price': '£47.09',
#   'title': 'Deep Under (Walker Security #1)'},
#  {'href': 'choosing-our-religion-the-spiritual-lives-of-americas-nones_14/index.html',
#   'price': '£28.42',
#   'title': "Choosing Our Religion: The Spiritual Lives of America's Nones"},
#  {'href': 'charlie-and-the-chocolate-factory-charlie-bucket-1_13/index.html',
#   'price': '£22.85',
#   'title': 'Charlie and the Chocolate Factory (Charlie Bucket #1)'},
#  {'href': 'charitys-cross-charles-towne-belles-4_12/index.html',
#   'price': '£41.24',
#   'title': "Charity's Cross (Charles Towne Belles #4)"},
#  {'href': 'bright-lines_11/index.html',
#   'price': '£39.07',
#   'title': 'Bright Lines'},
#  {'href': 'bridget-joness-diary-bridget-jones-1_10/index.html',
#   'price': '£29.82',
#   'title': "Bridget Jones's Diary (Bridget Jones #1)"},
#  {'href': 'bounty-colorado-mountain-7_9/index.html',
#   'price': '£37.26',
#   'title': 'Bounty (Colorado Mountain #7)'},
#  {'href': 'blood-defense-samantha-brinkman-1_8/index.html',
#   'price': '£20.30',
#   'title': 'Blood Defense (Samantha Brinkman #1)'},
#  {'href': 'bleach-vol-1-strawberry-and-the-soul-reapers-bleach-1_7/index.html',
#   'price': '£34.65',
#   'title': 'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)'},
#  {'href': 'beyond-good-and-evil_6/index.html',
#   'price': '£43.38',
#   'title': 'Beyond Good and Evil'},
#  {'href': 'alice-in-wonderland-alices-adventures-in-wonderland-1_5/index.html',
#   'price': '£55.53',
#   'title': "Alice in Wonderland (Alice's Adventures in Wonderland #1)"},
#  {'href': 'ajin-demi-human-volume-1-ajin-demi-human-1_4/index.html',
#   'price': '£57.06',
#   'title': 'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)'},
#  {'href': 'a-spys-devotion-the-regency-spies-of-london-1_3/index.html',
#   'price': '£16.97',
#   'title': "A Spy's Devotion (The Regency Spies of London #1)"},
#  {'href': '1st-to-die-womens-murder-club-1_2/index.html',
#   'price': '£53.98',
#   'title': "1st to Die (Women's Murder Club #1)"},
#  {'href': '1000-places-to-see-before-you-die_1/index.html',
#   'price': '£26.08',
#   'title': '1,000 Places to See Before You Die'}]

# %%
import pandas as pd

df = pd.DataFrame(infa)
print(df.shape)
df.head()
# Out:
# (20, 2)
#     price                                  title
# 0  £51.77                   A Light in the Attic
# 1  £53.74                     Tipping the Velvet
# 2  £50.10                             Soumission
# 3  £47.82                          Sharp Objects
# 4  £54.23  Sapiens: A Brief History of Humankind

# %%
def get_page(p):
    
    # изготовили ссылку
    url = 'http://books.toscrape.com/catalogue/page-{}.html'.format(p)
    
    # сходили по ней
    response = requests.get(url)
    
    # построили дерево 
    tree = BeautifulSoup(response.content, 'html.parser')
    
    # нашли в нём всё самое интересное
    books = tree.find_all('article', {'class' : 'product_pod'})
    
    infa = [ ]
    
    for book in books:
        infa.append({'price': book.find('p', {'class': 'price_color'}).text,
                     'href': book.h3.a.get('href'),
                     'title': book.h3.a.get('title')})
                     
    return infa

# %% [markdown]
# Осталось только пройтись по всем страничкам от page-1 до page-50 циклом и данные у нас в кармане.

# %%
infa = []

for p in range(1,51):
    infa.extend(get_page(p))

# %%
import pandas as pd

df = pd.DataFrame(infa)
print(df.shape)
df.head()
# Out:
# (1000, 3)
#     price  ...                                  title
# 0  £51.77  ...                   A Light in the Attic
# 1  £53.74  ...                     Tipping the Velvet
# 2  £50.10  ...                             Soumission
# 3  £47.82  ...                          Sharp Objects
# 4  £54.23  ...  Sapiens: A Brief History of Humankind
#
# [5 rows x 3 columns]

# %% [markdown]
# Кстати говоря, если перейти по ссылке в саму книгу, там о ней будет куча дополнительной информации. Можно пройтись по всем ссылкам и выкачать себе по ним дополнительную информацию.

# %%
df.to_excel('books.xls')

# %%
from google.colab import files
files.download('books.xls')
